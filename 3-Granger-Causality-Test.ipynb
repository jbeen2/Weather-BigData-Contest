# %% [markdown]
# # #3. Granger-Causality-Test

# %%
import numpy as np
import pandas as pd
import datetime as datetime
from tqdm.notebook import tqdm
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
tqdm.pandas()

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.api import VAR
from statsmodels.tsa.vector_ar.vecm import VECM
from statsmodels.tsa.vector_ar.vecm import coint_johansen, select_coint_rank
from statsmodels.tsa.stattools import coint
from statsmodels.tsa.stattools import grangercausalitytests

# %% [markdown]
# # 0. Data Load

# %% [markdown]
# ## 0-1. qty, cnt 등

# %%
final_data = pd.read_csv('최종데이터/final_categorical_0622.csv', encoding='cp949')
adf_corr = pd.read_csv('최종데이터/adf_corr_group_0617.csv', encoding='cp949')
final_data['date'] = final_data['date'].apply(lambda x : pd.to_datetime(x, format='%Y-%m-%d'))
final_data = final_data.merge(adf_corr[['sm_cat', 'group']], on='sm_cat')

# %%
# sh_data : [정상, high corr]
# ush_data : [비정상, high corr]
# sl_data : [정상, low corr]
# usl_data : [비정상, low corr]

sh_data = final_data[final_data.group=='정상_high']
ush_data = final_data[final_data.group=='비정상_high']
sl_data = final_data[final_data.group=='정상_low']
usl_data = final_data[final_data.group=='비정상_low']

# 정상 데이터 => VAR
# 비정상 데이터 => 공적분 관계가 존재하면 VECM
sh = sh_data[['date', 'age', 'sex', 'sm_cat', 'qty']].groupby(['date', 'sm_cat']).sum().reset_index()
sh = pd.pivot_table(sh, values='qty', index='date', columns='sm_cat').fillna(0)
ush = ush_data[['date', 'age', 'sex', 'sm_cat', 'qty']].groupby(['date', 'sm_cat']).sum().reset_index()
ush = pd.pivot_table(ush, values='qty', index='date', columns='sm_cat').fillna(0)

# qty와 상관관계가 높은 데이터만 사용
sh_item = sh.columns # sm_cat
ush_item = ush.columns # sm_cat

# %%
sh.head()
# Out:
# sm_cat      가스온수기   가자미  감/홍시  감말랭이   갓김치  건강즙/녹용  건어물 멸치  건어물 황태   건자두  \
# date
# 2018-01-01    0.0  21.0  50.0  27.0  26.0    70.0    60.0    47.0  37.0
# 2018-01-02    0.0  16.0  60.0  32.0  35.0   115.0    70.0    81.0  36.0
# 2018-01-03    0.0  17.0  51.0  28.0  19.0    84.0    88.0    56.0  37.0
# 2018-01-04    0.0  12.0  58.0  30.0  28.0   135.0    89.0    57.0  34.0
# 2018-01-05    0.0  24.0  48.0  23.0  21.0    82.0    64.0    41.0  31.0
#
# sm_cat        견과류  ...   풋패치    한우육  해조류 다시마  해조류 미역  헤어스타일링용 펌제  헤어케어세트  \
# date               ...
# 2018-01-01  256.0  ...  29.0  169.0     21.0    50.0        38.0    40.0
# 2018-01-02  247.0  ...  46.0  205.0     30.0    74.0        95.0    45.0
# 2018-01-03  165.0  ...  39.0  209.0     20.0    64.0        94.0    45.0
# 2018-01-04  186.0  ...  46.0  144.0     30.0    60.0        61.0    30.0
# 2018-01-05  160.0  ...  28.0  138.0     30.0    60.0        64.0    28.0
#
# sm_cat       혼합견과    홍어  화장 비누       회
# date
# 2018-01-01   70.0   7.0  216.0   847.0
# 2018-01-02   96.0   5.0  343.0   974.0
# 2018-01-03  107.0   7.0  332.0  1287.0
# 2018-01-04   75.0  20.0  301.0  1424.0
# 2018-01-05   67.0   4.0  202.0  1340.0
#
# [5 rows x 130 columns]

# %% [markdown]
# ## 0-2. weather

# %%
var_list = ['date', 'avg_ta', 'max_ta', 'min_ta', 'avg_ws', 'PM10', 'PM25', 'hm_max', 'sum_ss_hr', 'max_pa']
weather = sh_data.groupby(['date']).mean().reset_index()[var_list]
weather.index = weather['date']
weather = weather.drop('date', axis=1)

# %% [markdown]
# # 1. Granger Causality Test

# %% [markdown]
# * 두 시계열 변수 모두 정상이면 → VAR 모델 적합 후 그래인저 인과관계 도출
# * 두 시계열 변수 중 하나라도 비정상이면 → 공적분 검정 → 유의한 공적분 관계가 존재하면 VECM 모델 적합 후 인과관계 도출 → 유의한 공적분 관계가 존재하지 않으면 데이터 차분. VAR 모델 적합 후 인과관계 도출

# %% [markdown]
# ## 1-1. 정상 상품

# %%
st_weather = ['avg_ws', 'PM10', 'PM25', 'sum_ss_hr'] # 정상 시계열 날씨
nst_weather = ['avg_ta', 'max_ta', 'min_ta', 'hm_max', 'max_pa'] # 비정상 시계열 날씨

# %% [markdown]
# ### 1-1-1. 정상 상품과 정상 날씨

# %%
# 최적 시차에서 VAR 모델링 후, 그래인저 인과관계 도출하는 함수 

def VAR_granger(data, weather, sm_cat, w_var):
    x = pd.concat([weather[w_var], data[sm_cat]], axis=1)
    forecasting_model = VAR(x)
    results_aic = []
    for p in range(1,10): # 최적 시차 찾기
        results = forecasting_model.fit(p)
        results_aic.append(results.aic)
    model = VAR(x)
    lag = np.argmin(results_aic) + 1
    var_res = model.fit(lag)
    g_res = var_res.test_causality(caused=sm_cat, causing=w_var)
    if g_res.pvalue <= 0.05:
        reject = 'causality'
    else:
        reject = 'None'
    return pd.DataFrame([{'sm_cat':sm_cat, 'weather':w_var, 'var_lag':lag, 'granger_reject':reject}])

# %%
# ===== ADF 확인 =====
adf_sh = pd.DataFrame()

def adf_test(data, sm_cat):
    item = data[sm_cat]
    result = adfuller(item.values)
    if result[1] <= 0.05:
        test_res = '정상' # 기각
    else:
        test_res = '비정상' # 기각하지 못함 
    return pd.DataFrame([{'sm_cat':sm_cat, 'ADF_stats':result[0], 'p-value':result[1], 'test_res':test_res}])

for sm_cat in sh_item:
    adf_sh = pd.concat([adf_sh, adf_test(sh, sm_cat)], axis=0)

# %%
warnings.filterwarnings('ignore')
sh_var_res = pd.DataFrame()

for w in st_weather:
    for sm_cat in sh_item:
        result = VAR_granger(sh, weather, sm_cat, w)
        sh_var_res = pd.concat([sh_var_res, result], axis=0)

# %%
for w in st_weather:
    print('===== Granger Causality : {} ====='.format(w))
    print(sh_var_res.loc[sh_var_res.weather==w, 'granger_reject'].value_counts())
    print(' ')
# Out:
# ===== Granger Causality : avg_ws =====
# None         117
# causality     13
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : PM10 =====
# None         105
# causality     25
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : PM25 =====
# None         111
# causality     19
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : sum_ss_hr =====
# None         115
# causality     15
# Name: granger_reject, dtype: int64

# %%
sh_var_pivot = pd.pivot_table(sh_var_res, index='sm_cat', values='granger_reject', columns='weather', aggfunc='first')
sh_var_pivot
# Out:
# weather                 PM10       PM25     avg_ws  sum_ss_hr
# sm_cat
# 가스온수기              causality       None       None       None
# 가자미                     None       None       None       None
# 감/홍시                    None       None       None       None
# 감말랭이                    None       None       None  causality
# 갓김치                causality       None       None       None
# 건강즙/녹용                  None       None       None       None
# 건어물 멸치                  None       None       None       None
# 건어물 황태                  None       None       None       None
# 건자두                     None       None       None       None
# 견과류                     None       None  causality       None
# 견과류 땅콩                  None       None       None       None
# 견과류 마카다미아               None       None  causality       None
# 견과류 잣/은행                None       None       None       None
# 견과류 캐슈넛                 None       None       None       None
# 견과류 호두             causality       None       None       None
# 계란                      None       None       None       None
# 공기정화 용품            causality  causality       None       None
# 공기청정기              causality  causality       None       None
# 곶감/반건시                  None       None       None       None
# 과채 음료/주스                None       None       None  causality
# 기능성 링클케어 화장품            None       None  causality       None
# 기능성 영양보습 화장품            None       None       None       None
# 기초 화장용 에센스              None       None       None       None
# 기초 화장용 오일/앰플            None       None  causality  causality
# 기타 농산물                  None       None       None       None
# 기타 한방/환제품               None       None       None       None
# 나물                      None       None       None       None
# 남성 메이크업                 None       None       None       None
# 남성 스킨              causality  causality       None       None
# 남성 에센스                  None       None       None       None
# 남성 크림              causality  causality       None       None
# 남성 클렌징                  None       None       None       None
# 냉풍기                     None       None       None       None
# 네일 메이크업 용품              None       None       None       None
# 네일리무버                   None       None       None       None
# 네일세트                    None       None       None       None
# 네일아트                    None       None       None  causality
# 네일컬러                    None       None       None       None
# 네일케어                    None       None       None       None
# 녹차                      None       None       None       None
# 닭 양념육                   None       None       None  causality
# 더치커피                    None       None       None       None
# 도라지/더덕                  None       None       None       None
# 돈풍기                     None       None  causality       None
# 랍스타                     None  causality       None       None
# 레몬/자몽                   None       None       None       None
# 린스                 causality  causality       None       None
# 립앤아이 리무버                None       None       None       None
# 멀티형 에어컨                 None       None       None  causality
# 메이크업 박스            causality       None       None       None
# 무/배추               causality  causality       None       None
# 바나나/파인애플/망고             None       None       None  causality
# 바디 세트              causality  causality  causality       None
# 바디케어용 때비누               None       None       None       None
# 바디케어용 슬리밍               None       None       None       None
# 반건조고구마             causality  causality  causality  causality
# 반찬류                     None       None       None       None
# 배/포도/과일즙                None       None       None       None
# 백김치                     None       None       None       None
# 베이스 메이크업 세트             None       None       None       None
# 베이스 메이크업용 BB크림     causality  causality       None       None
# 베이스 메이크업용 CC크림          None       None  causality       None
# 베이스 메이크업용 메이크업베이스  causality       None       None       None
# 베이스 메이크업용 컨실러           None       None       None       None
# 베이스 메이크업용 쿠션팩트          None       None       None       None
# 벽걸이형 냉온풍기               None       None       None  causality
# 보일러                     None       None       None       None
# 뷰티 속눈썹/쌍꺼풀              None       None       None       None
# 뷰티용 기름종이                None       None       None       None
# 뷰티용 뷰러             causality  causality       None       None
# 뷰티용 여드름압출기         causality  causality       None       None
# 삼치                 causality       None       None       None
# 색조 메이크업 립글로스            None       None       None       None
# 색조 메이크업 립스틱             None       None       None       None
# 색조 메이크업 마스카라       causality  causality       None       None
# 색조 메이크업 볼터치             None       None  causality       None
# 색조 메이크업 속눈썹영양제          None       None       None       None
# 색조 메이크업 쉐딩/하이라이터        None       None       None       None
# 색조 메이크업 아이라이너           None       None       None       None
# 생닭/닭부분육                 None       None       None       None
# 생선류                     None       None       None       None
# 생수                      None       None       None  causality
# 샤워코롱                    None       None       None       None
# 선크림                causality       None       None  causality
# 소고기 등심/안심               None  causality       None       None
# 수산 생물                   None       None       None       None
# 스킨케어 수면팩                None       None       None       None
# 스킨케어 코팩                 None       None       None       None
# 스킨케어 필오프팩               None       None       None       None
# 스탠드형 냉온풍기               None       None       None       None
# 스탠드형 에어컨                None       None       None       None
# 아몬드유/코코넛밀크              None       None       None       None
# 어란(생선알)                 None       None       None       None
# 에이드                     None       None  causality  causality
# 오징어                     None       None       None       None
# 옥수수                     None       None       None       None
# 옻/칡/쑥즙             causality  causality       None       None
# 유제품 음료                  None       None       None       None
# 의류건조기              causality  causality       None       None
# 이온음료                    None       None       None  causality
# 인삼/수삼/산삼                None       None       None       None
# 인스턴트커피             causality       None       None       None
# 전복 생물                   None       None       None       None
# 전통주                     None       None       None       None
# 절임배추/김치속           causality       None       None       None
# 젓갈류                     None       None       None       None
# 제습기                     None       None       None       None
# 차 선물세트                  None       None       None       None
# 차/곡물 음료                 None       None       None       None
# 천장형 에어컨                 None       None       None  causality
# 카페 푸드                   None       None       None       None
# 클렌징 크림                  None       None       None       None
# 클렌징 폼                   None       None       None  causality
# 키위/참다래                  None       None       None       None
# 태닝용 선크림                 None  causality       None       None
# 팩도구                     None       None  causality       None
# 표고버섯                    None       None  causality       None
# 풋스프레이                   None       None       None       None
# 풋워시/스크럽                 None       None       None       None
# 풋크림                     None       None       None       None
# 풋패치                     None       None       None       None
# 한우육                     None       None       None       None
# 해조류 다시마            causality  causality  causality       None
# 해조류 미역                  None       None       None       None
# 헤어스타일링용 펌제              None       None       None       None
# 헤어케어세트             causality       None       None       None
# 혼합견과                    None       None       None       None
# 홍어                      None  causality       None       None
# 화장 비누                   None       None       None       None
# 회                       None       None       None       None

# %% [markdown]
# ### 1-1-2. 정상 상품과 비정상 날씨

# %% [markdown]
# **공적분(Cointegration) 관계**
# * 두 비정상적 시계열 x, y의 결합에 의해 생기는 잔차 e가 정상이면, 유의한 공적분 관계가 존재함을 의미
# * x, y간 장기적인 균형관계 (장기적으로 봤을 때 서로 영향을 적당히 미친다). 공적분 관계가 성립함을 확인한 후, VECM으로 예측
# * rank=0 : p-vector의 경우 p개의 단위근을 가지는 불안정한 시계열 = 비정상 시계열

# %% [markdown]
# #### 공적분(Cointegration) 검정

# %%
# 공적분 검정 함수
def co_test(data, weather, sm_cat, w_var):
    score, p_value, _ = coint(data[sm_cat], weather[w_var]) # coint(y, x)
    if p_value <= 0.05:
        test_res = '공적분' # 장기적으로 유의한 관계가 있다
    else:
        test_res = 'None' # 장기적으로 유의한 관계가 없다
    return pd.DataFrame([{'sm_cat':sm_cat, w_var:test_res}])

# %%
sh_co_res = pd.DataFrame()
for i in range(len(nst_weather)):
    w_sample = weather[nst_weather[i]]
    res = pd.DataFrame()
    for sm_cat in sh_item:
        res = pd.concat([res, co_test(sh, weather, sm_cat, nst_weather[i])], axis=0)
    if i == 0:
        sh_co_res = pd.concat([sh_co_res, res], axis=1)
    else:
        sh_co_res = pd.concat([sh_co_res, res.drop(['sm_cat'], axis=1)], axis=1) # 정상qty와 비정상날씨 간 공적분이 존재할 경우, vecm 적합 가능

# %%
sh_co_res # 정상qty와 비정상날씨 간 공적분이 존재할 경우, vecm 적합 가능
# Out:
#               sm_cat avg_ta max_ta min_ta hm_max max_pa
# 0              가스온수기    공적분    공적분    공적분    공적분    공적분
# 0                가자미    공적분    공적분    공적분    공적분    공적분
# 0               감/홍시    공적분    공적분    공적분    공적분    공적분
# 0               감말랭이    공적분    공적분    공적분    공적분    공적분
# 0                갓김치    공적분    공적분    공적분    공적분    공적분
# 0             건강즙/녹용    공적분    공적분    공적분    공적분    공적분
# 0             건어물 멸치    공적분    공적분    공적분    공적분    공적분
# 0             건어물 황태    공적분    공적분    공적분    공적분    공적분
# 0                건자두    공적분    공적분    공적분    공적분    공적분
# 0                견과류    공적분    공적분    공적분    공적분    공적분
# 0             견과류 땅콩    공적분    공적분    공적분    공적분    공적분
# 0          견과류 마카다미아    공적분    공적분    공적분    공적분    공적분
# 0           견과류 잣/은행    공적분    공적분    공적분    공적분    공적분
# 0            견과류 캐슈넛   None   None   None   None   None
# 0             견과류 호두    공적분    공적분    공적분    공적분    공적분
# 0                 계란    공적분    공적분    공적분   None    공적분
# 0            공기정화 용품    공적분    공적분    공적분    공적분    공적분
# 0              공기청정기    공적분    공적분    공적분    공적분    공적분
# 0             곶감/반건시    공적분    공적분    공적분    공적분    공적분
# 0           과채 음료/주스    공적분    공적분    공적분    공적분   None
# 0       기능성 링클케어 화장품    공적분    공적분    공적분    공적분    공적분
# 0       기능성 영양보습 화장품    공적분    공적분    공적분    공적분    공적분
# 0         기초 화장용 에센스    공적분    공적분    공적분    공적분    공적분
# 0       기초 화장용 오일/앰플    공적분    공적분    공적분    공적분   None
# 0             기타 농산물    공적분    공적분    공적분    공적분    공적분
# 0          기타 한방/환제품    공적분    공적분    공적분    공적분    공적분
# 0                 나물    공적분    공적분    공적분    공적분    공적분
# 0            남성 메이크업   None   None    공적분   None    공적분
# 0              남성 스킨    공적분    공적분    공적분    공적분    공적분
# 0             남성 에센스    공적분    공적분    공적분    공적분    공적분
# 0              남성 크림    공적분    공적분    공적분    공적분    공적분
# 0             남성 클렌징    공적분    공적분    공적분    공적분    공적분
# 0                냉풍기    공적분    공적분    공적분    공적분    공적분
# 0         네일 메이크업 용품    공적분    공적분    공적분    공적분    공적분
# 0              네일리무버    공적분    공적분    공적분    공적분    공적분
# 0               네일세트    공적분    공적분    공적분    공적분    공적분
# 0               네일아트    공적분    공적분    공적분    공적분    공적분
# 0               네일컬러    공적분    공적분    공적분    공적분    공적분
# 0               네일케어   None   None   None    공적분    공적분
# 0                 녹차    공적분    공적분    공적분    공적분    공적분
# 0              닭 양념육   None   None   None   None    공적분
# 0               더치커피    공적분    공적분    공적분   None   None
# 0             도라지/더덕    공적분    공적분    공적분    공적분   None
# 0                돈풍기    공적분    공적분    공적분    공적분   None
# 0                랍스타    공적분    공적분    공적분    공적분    공적분
# 0              레몬/자몽    공적분    공적분    공적분    공적분    공적분
# 0                 린스    공적분    공적분    공적분    공적분    공적분
# 0           립앤아이 리무버    공적분    공적분    공적분    공적분   None
# 0            멀티형 에어컨   None   None   None   None   None
# 0            메이크업 박스    공적분    공적분    공적분    공적분    공적분
# 0               무/배추    공적분    공적분    공적분    공적분    공적분
# 0        바나나/파인애플/망고   None   None   None   None   None
# 0              바디 세트    공적분    공적분    공적분    공적분    공적분
# 0          바디케어용 때비누    공적분    공적분    공적분    공적분    공적분
# 0          바디케어용 슬리밍    공적분    공적분    공적분    공적분    공적분
# 0             반건조고구마    공적분    공적분    공적분    공적분    공적분
# 0                반찬류   None   None   None   None    공적분
# 0           배/포도/과일즙    공적분    공적분    공적분    공적분    공적분
# 0                백김치    공적분    공적분    공적분    공적분    공적분
# 0        베이스 메이크업 세트    공적분    공적분    공적분    공적분    공적분
# 0     베이스 메이크업용 BB크림    공적분    공적분    공적분    공적분    공적분
# 0     베이스 메이크업용 CC크림    공적분    공적분    공적분    공적분    공적분
# 0  베이스 메이크업용 메이크업베이스    공적분    공적분    공적분    공적분    공적분
# 0      베이스 메이크업용 컨실러    공적분    공적분    공적분    공적분    공적분
# 0     베이스 메이크업용 쿠션팩트   None   None   None   None   None
# 0          벽걸이형 냉온풍기    공적분    공적분    공적분   None   None
# 0                보일러    공적분    공적분    공적분    공적분    공적분
# 0         뷰티 속눈썹/쌍꺼풀    공적분    공적분    공적분    공적분   None
# 0           뷰티용 기름종이    공적분    공적분    공적분    공적분    공적분
# 0             뷰티용 뷰러    공적분    공적분    공적분    공적분    공적분
# 0         뷰티용 여드름압출기    공적분    공적분    공적분    공적분    공적분
# 0                 삼치    공적분    공적분    공적분    공적분    공적분
# 0       색조 메이크업 립글로스    공적분    공적분    공적분    공적분    공적분
# 0        색조 메이크업 립스틱    공적분    공적분    공적분    공적분   None
# 0       색조 메이크업 마스카라    공적분    공적분    공적분    공적분    공적분
# 0        색조 메이크업 볼터치    공적분    공적분    공적분    공적분    공적분
# 0     색조 메이크업 속눈썹영양제    공적분    공적분    공적분    공적분    공적분
# 0   색조 메이크업 쉐딩/하이라이터    공적분    공적분    공적분    공적분    공적분
# 0      색조 메이크업 아이라이너    공적분    공적분    공적분    공적분    공적분
# 0            생닭/닭부분육    공적분    공적분    공적분    공적분    공적분
# 0                생선류    공적분    공적분    공적분    공적분    공적분
# 0                 생수   None   None   None   None   None
# 0               샤워코롱    공적분    공적분    공적분    공적분    공적분
# 0                선크림   None   None   None   None   None
# 0          소고기 등심/안심    공적분    공적분    공적분    공적분    공적분
# 0              수산 생물    공적분    공적분    공적분    공적분    공적분
# 0           스킨케어 수면팩    공적분    공적분    공적분    공적분    공적분
# 0            스킨케어 코팩    공적분    공적분    공적분    공적분    공적분
# 0          스킨케어 필오프팩    공적분    공적분    공적분    공적분    공적분
# 0          스탠드형 냉온풍기   None   None   None   None   None
# 0           스탠드형 에어컨   None   None   None   None   None
# 0         아몬드유/코코넛밀크    공적분    공적분    공적분    공적분    공적분
# 0            어란(생선알)   None   None   None   None   None
# 0                에이드   None   None   None    공적분    공적분
# 0                오징어    공적분    공적분    공적분    공적분    공적분
# 0                옥수수    공적분    공적분    공적분   None    공적분
# 0             옻/칡/쑥즙    공적분    공적분    공적분    공적분    공적분
# 0             유제품 음료   None   None   None    공적분    공적분
# 0              의류건조기    공적분   None    공적분   None   None
# 0               이온음료    공적분    공적분    공적분   None   None
# 0           인삼/수삼/산삼    공적분    공적분    공적분    공적분    공적분
# 0             인스턴트커피    공적분    공적분    공적분    공적분   None
# 0              전복 생물    공적분    공적분    공적분    공적분    공적분
# 0                전통주    공적분    공적분    공적분    공적분    공적분
# 0           절임배추/김치속    공적분    공적분    공적분    공적분    공적분
# 0                젓갈류    공적분    공적분    공적분    공적분    공적분
# 0                제습기    공적분    공적분    공적분    공적분    공적분
# 0             차 선물세트    공적분    공적분    공적분    공적분    공적분
# 0            차/곡물 음료    공적분    공적분    공적분    공적분    공적분
# 0            천장형 에어컨    공적분    공적분    공적분    공적분    공적분
# 0              카페 푸드    공적분    공적분    공적분    공적분   None
# 0             클렌징 크림    공적분    공적분    공적분    공적분    공적분
# 0              클렌징 폼   None   None   None   None   None
# 0             키위/참다래    공적분    공적분    공적분    공적분   None
# 0            태닝용 선크림    공적분    공적분    공적분   None   None
# 0                팩도구   None   None   None   None    공적분
# 0               표고버섯    공적분    공적분    공적분    공적분    공적분
# 0              풋스프레이   None   None   None   None   None
# 0            풋워시/스크럽    공적분    공적분    공적분    공적분    공적분
# 0                풋크림    공적분    공적분    공적분    공적분    공적분
# 0                풋패치    공적분    공적분    공적분    공적분    공적분
# 0                한우육    공적분    공적분    공적분    공적분    공적분
# 0            해조류 다시마    공적분    공적분    공적분    공적분    공적분
# 0             해조류 미역    공적분    공적분    공적분    공적분    공적분
# 0         헤어스타일링용 펌제    공적분    공적분    공적분    공적분    공적분
# 0             헤어케어세트    공적분    공적분    공적분    공적분    공적분
# 0               혼합견과    공적분    공적분    공적분    공적분    공적분
# 0                 홍어    공적분    공적분    공적분    공적분   None
# 0              화장 비누    공적분    공적분    공적분    공적분    공적분
# 0                  회    공적분    공적분    공적분    공적분   None

# %% [markdown]
# #### VECM & Granger causality Test

# %%
# print된 결과를 변수에 저장하는 함수

from io import StringIO 
import sys

class Capturing(list):
    def __enter__(self):
        self._stdout = sys.stdout
        sys.stdout = self._stringio = StringIO()
        return self
    def __exit__(self, *args):
        self.extend(self._stringio.getvalue().splitlines())
        del self._stringio    # free up some memory
        sys.stdout = self._stdout
        
# VECM 모델링 후, 그래인저 인과관계를 도출하는 함수
def VECM_granger(data, weather, sm_cat, w_var):
    x = pd.concat([weather[w_var], data[sm_cat]], axis=1)
    vec_rank = select_coint_rank(x, det_order = -1, k_ar_diff = 2, method = 'trace', signif=0.01).rank
    model = VECM(x, k_ar_diff=2, coint_rank=vec_rank)
    vecm_res = model.fit()
    g_res = vecm_res.test_granger_causality(caused=sm_cat, causing=w_var)
    with Capturing() as output:
        print(g_res.summary()[1][2])
    if float(output[0]) <= 0.05:
        reject = 'causality'
    else:
        reject = 'None'
    return pd.DataFrame([{'sm_cat':sm_cat, 'weather':w_var, 'granger_reject':reject}])

# %%
# 그래인저 인과관계 검정
sh_vecm_res = pd.DataFrame()

for w_var in nst_weather:
    for sm_cat in sh_item:
        # 공적분 관계가 유의할 때, 그래인저 인과관계 분석
        if (sh_co_res.loc[sh_co_res.sm_cat==sm_cat, w_var] == '공적분').values: 
            result = VECM_granger(sh, weather, sm_cat, w_var)
        else:
            result = pd.DataFrame([{'sm_cat':sm_cat, 'weather':w_var, 'granger_reject':'None'}])
        sh_vecm_res = pd.concat([sh_vecm_res, result], axis=0)

# %%
sh_vecm_res
# Out:
#     sm_cat weather granger_reject
# 0    가스온수기  avg_ta           None
# 0      가자미  avg_ta      causality
# 0     감/홍시  avg_ta           None
# 0     감말랭이  avg_ta           None
# 0      갓김치  avg_ta      causality
# ..     ...     ...            ...
# 0   헤어케어세트  max_pa           None
# 0     혼합견과  max_pa           None
# 0       홍어  max_pa           None
# 0    화장 비누  max_pa           None
# 0        회  max_pa           None
#
# [650 rows x 3 columns]

# %%
for w in nst_weather:
    print('===== Granger Causality : {} ====='.format(w))
    print(sh_vecm_res.loc[sh_vecm_res.weather==w, 'granger_reject'].value_counts())
    print(' ')
# Out:
# ===== Granger Causality : avg_ta =====
# None         101
# causality     29
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : max_ta =====
# None         96
# causality    34
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : min_ta =====
# None         117
# causality     13
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : hm_max =====
# None         100
# causality     30
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : max_pa =====
# None         118
# causality     12
# Name: granger_reject, dtype: int64

# %%
sh_vecm_pivot = pd.pivot_table(sh_vecm_res, index='sm_cat', values='granger_reject', columns='weather', aggfunc='first')
sh_vecm_pivot
# Out:
# weather               avg_ta     hm_max     max_pa     max_ta     min_ta
# sm_cat
# 가스온수기                   None       None       None       None       None
# 가자미                causality       None       None       None       None
# 감/홍시                    None       None       None       None       None
# 감말랭이                    None       None       None       None       None
# 갓김치                causality       None       None  causality  causality
# 건강즙/녹용                  None  causality       None       None       None
# 건어물 멸치                  None       None  causality       None       None
# 건어물 황태                  None  causality       None       None  causality
# 건자두                     None       None  causality       None       None
# 견과류                causality       None  causality  causality       None
# 견과류 땅콩             causality       None       None  causality  causality
# 견과류 마카다미아          causality       None       None  causality       None
# 견과류 잣/은행                None       None  causality       None       None
# 견과류 캐슈넛                 None       None       None       None       None
# 견과류 호두                  None       None       None       None       None
# 계란                      None       None       None       None       None
# 공기정화 용품                 None       None       None  causality       None
# 공기청정기              causality       None       None  causality  causality
# 곶감/반건시                  None       None       None       None       None
# 과채 음료/주스           causality       None       None  causality       None
# 기능성 링클케어 화장품       causality  causality       None  causality  causality
# 기능성 영양보습 화장품       causality       None       None  causality       None
# 기초 화장용 에센스              None       None       None       None       None
# 기초 화장용 오일/앰플            None       None       None       None       None
# 기타 농산물                  None  causality       None       None       None
# 기타 한방/환제품               None       None  causality       None       None
# 나물                      None  causality       None       None       None
# 남성 메이크업                 None       None       None       None       None
# 남성 스킨              causality  causality       None       None       None
# 남성 에센스                  None       None       None       None       None
# 남성 크림                   None  causality       None       None       None
# 남성 클렌징                  None       None       None  causality       None
# 냉풍기                     None       None       None       None       None
# 네일 메이크업 용품              None       None       None       None       None
# 네일리무버              causality  causality  causality       None       None
# 네일세트               causality       None       None  causality       None
# 네일아트                    None       None       None       None  causality
# 네일컬러               causality       None       None  causality       None
# 네일케어                    None       None       None       None       None
# 녹차                 causality  causality       None  causality       None
# 닭 양념육                   None       None       None       None       None
# 더치커피                    None       None       None  causality       None
# 도라지/더덕                  None       None       None       None       None
# 돈풍기                causality       None       None       None       None
# 랍스타                     None       None       None       None       None
# 레몬/자몽              causality  causality       None  causality       None
# 린스                 causality       None       None  causality       None
# 립앤아이 리무버                None       None       None       None       None
# 멀티형 에어컨                 None       None       None       None       None
# 메이크업 박스                 None       None       None       None       None
# 무/배추                    None       None       None       None       None
# 바나나/파인애플/망고             None       None       None       None       None
# 바디 세트                   None       None       None       None       None
# 바디케어용 때비누               None       None       None       None       None
# 바디케어용 슬리밍               None       None       None       None       None
# 반건조고구마                  None  causality       None       None       None
# 반찬류                     None       None       None       None       None
# 배/포도/과일즙                None  causality       None       None       None
# 백김치                     None  causality       None       None       None
# 베이스 메이크업 세트             None       None       None       None       None
# 베이스 메이크업용 BB크림          None  causality       None  causality       None
# 베이스 메이크업용 CC크림          None       None       None       None       None
# 베이스 메이크업용 메이크업베이스       None       None       None       None       None
# 베이스 메이크업용 컨실러           None       None       None       None       None
# 베이스 메이크업용 쿠션팩트          None       None       None       None       None
# 벽걸이형 냉온풍기          causality       None       None  causality  causality
# 보일러                causality  causality       None       None       None
# 뷰티 속눈썹/쌍꺼풀              None  causality       None       None       None
# 뷰티용 기름종이           causality  causality       None  causality       None
# 뷰티용 뷰러                  None       None       None  causality       None
# 뷰티용 여드름압출기              None       None  causality  causality       None
# 삼치                      None  causality       None       None       None
# 색조 메이크업 립글로스       causality       None       None  causality       None
# 색조 메이크업 립스틱             None       None       None       None       None
# 색조 메이크업 마스카라            None       None       None       None  causality
# 색조 메이크업 볼터치             None  causality       None       None       None
# 색조 메이크업 속눈썹영양제          None       None       None       None       None
# 색조 메이크업 쉐딩/하이라이터        None  causality       None       None       None
# 색조 메이크업 아이라이너           None       None       None       None       None
# 생닭/닭부분육                 None       None       None       None       None
# 생선류                     None       None       None       None       None
# 생수                      None       None       None       None       None
# 샤워코롱                    None       None       None  causality       None
# 선크림                     None       None       None       None       None
# 소고기 등심/안심               None       None       None       None       None
# 수산 생물                   None       None  causality       None  causality
# 스킨케어 수면팩                None       None       None       None       None
# 스킨케어 코팩            causality       None       None  causality       None
# 스킨케어 필오프팩               None       None       None       None       None
# 스탠드형 냉온풍기               None       None       None       None       None
# 스탠드형 에어컨                None       None       None       None       None
# 아몬드유/코코넛밀크              None  causality       None       None       None
# 어란(생선알)                 None       None       None       None       None
# 에이드                     None       None       None       None       None
# 오징어                     None       None       None       None       None
# 옥수수                     None       None       None       None       None
# 옻/칡/쑥즙                  None  causality  causality       None  causality
# 유제품 음료                  None       None       None       None       None
# 의류건조기                   None       None       None       None       None
# 이온음료               causality       None       None  causality       None
# 인삼/수삼/산삼                None       None       None       None       None
# 인스턴트커피             causality  causality       None  causality       None
# 전복 생물                   None       None  causality       None       None
# 전통주                     None       None       None       None       None
# 절임배추/김치속                None  causality       None       None       None
# 젓갈류                     None  causality       None       None       None
# 제습기                     None       None  causality       None       None
# 차 선물세트                  None       None       None       None       None
# 차/곡물 음료                 None  causality       None  causality       None
# 천장형 에어컨            causality       None       None  causality  causality
# 카페 푸드              causality       None       None  causality  causality
# 클렌징 크림             causality       None       None  causality       None
# 클렌징 폼                   None       None       None       None       None
# 키위/참다래                  None       None       None       None       None
# 태닝용 선크림            causality       None       None  causality  causality
# 팩도구                     None       None       None       None       None
# 표고버섯                    None  causality       None       None       None
# 풋스프레이                   None       None       None       None       None
# 풋워시/스크럽                 None  causality  causality       None       None
# 풋크림                     None       None       None  causality       None
# 풋패치                     None       None       None       None       None
# 한우육                     None       None       None       None       None
# 해조류 다시마                 None       None       None  causality       None
# 해조류 미역                  None       None       None       None       None
# 헤어스타일링용 펌제         causality       None       None  causality       None
# 헤어케어세트                  None  causality       None       None       None
# 혼합견과                    None       None       None       None       None
# 홍어                      None       None       None       None       None
# 화장 비누                   None  causality       None       None       None
# 회                       None       None       None       None       None

# %% [markdown]
# ### 1-1-3. 정상 상품 최종 인과관계

# %%
sh_granger = pd.concat([sh_vecm_pivot, sh_var_pivot], axis=1).reset_index()
sh_granger['total'] = np.sum(sh_granger.iloc[:,1:]=='causality', axis=1) # 인과관계가 있는 feature 개수

sh_granger.head()
# Out:
# weather sm_cat     avg_ta hm_max max_pa  ...  PM25 avg_ws  sum_ss_hr total
# 0        가스온수기       None   None   None  ...  None   None       None     1
# 1          가자미  causality   None   None  ...  None   None       None     1
# 2         감/홍시       None   None   None  ...  None   None       None     0
# 3         감말랭이       None   None   None  ...  None   None  causality     1
# 4          갓김치  causality   None   None  ...  None   None       None     4
#
# [5 rows x 11 columns]

# %%
print('인과관계가 하나라도 있는 상품의 개수 : {}'.format(len(sh_granger[sh_granger.total>0].sm_cat)))
print('인과관계가 하나도 없는 상품의 개수 : {}'.format(len(sh_granger[sh_granger.total==0].sm_cat)))
# Out:
# 인과관계가 하나라도 있는 상품의 개수 : 89
# 인과관계가 하나도 없는 상품의 개수 : 41

# %%
sh_granger[sh_granger.total>0].sm_cat.unique() # 인과관계가 하나라도 있는 상품
# Out:
# array(['가스온수기', '가자미', '감말랭이', '갓김치', '건강즙/녹용', '건어물 멸치', '건어물 황태', '건자두',
#        '견과류', '견과류 땅콩', '견과류 마카다미아', '견과류 잣/은행', '견과류 호두', '공기정화 용품',
#        '공기청정기', '과채 음료/주스', '기능성 링클케어 화장품', '기능성 영양보습 화장품',
#        '기초 화장용 오일/앰플', '기타 농산물', '기타 한방/환제품', '나물', '남성 스킨', '남성 크림',
#        '남성 클렌징', '네일리무버', '네일세트', '네일아트', '네일컬러', '녹차', '닭 양념육', '더치커피',
#        '돈풍기', '랍스타', '레몬/자몽', '린스', '멀티형 에어컨', '메이크업 박스', '무/배추',
#        '바나나/파인애플/망고', '바디 세트', '반건조고구마', '배/포도/과일즙', '백김치',
#        '베이스 메이크업용 BB크림', '베이스 메이크업용 CC크림', '베이스 메이크업용 메이크업베이스',
#        '벽걸이형 냉온풍기', '보일러', '뷰티 속눈썹/쌍꺼풀', '뷰티용 기름종이', '뷰티용 뷰러',
#        '뷰티용 여드름압출기', '삼치', '색조 메이크업 립글로스', '색조 메이크업 마스카라', '색조 메이크업 볼터치',
#        '색조 메이크업 쉐딩/하이라이터', '생수', '샤워코롱', '선크림', '소고기 등심/안심', '수산 생물',
#        '스킨케어 코팩', '아몬드유/코코넛밀크', '에이드', '옻/칡/쑥즙', '의류건조기', '이온음료',
#        '인스턴트커피', '전복 생물', '절임배추/김치속', '젓갈류', '제습기', '차/곡물 음료', '천장형 에어컨',
#        '카페 푸드', '클렌징 크림', '클렌징 폼', '태닝용 선크림', '팩도구', '표고버섯', '풋워시/스크럽',
#        '풋크림', '해조류 다시마', '헤어스타일링용 펌제', '헤어케어세트', '홍어', '화장 비누'],
#       dtype=object)

# %% [markdown]
# ## 1-2. 비정상 상품

# %% [markdown]
# ### 1-2-1. 비정상 상품과 정상 날씨

# %% [markdown]
# #### 공적분 검정

# %%
ush_co_res = pd.DataFrame()
for i in range(len(st_weather)):
    w_sample = weather[st_weather[i]]
    res = pd.DataFrame()
    for sm_cat in ush_item:
        res = pd.concat([res, co_test(ush, weather, sm_cat, st_weather[i])], axis=0)
    if i == 0:
        ush_co_res = pd.concat([ush_co_res, res], axis=1)
    else:
        ush_co_res = pd.concat([ush_co_res, res.drop(['sm_cat'], axis=1)], axis=1) # 비정상qty와 정상날씨 간 공적분이 존재할 경우, vecm 적합 가능

# %%
ush_co_res # 정상qty와 비정상날씨 간 공적분이 존재할 경우, vecm 적합 가능
# Out:
#           sm_cat avg_ws  PM10  PM25 sum_ss_hr
# 0        가열식 가습기   None  None  None      None
# 0   갈비/찜/바비큐용 돈육    공적분  None   공적분      None
# 0     감귤/한라봉/오렌지   None  None  None      None
# 0             감자   None  None  None      None
# 0            건대추   None  None  None      None
# 0        건어물 진미채   None  None  None      None
# 0            건포도   None  None  None      None
# 0            게장류   None  None  None      None
# 0          견과류 밤   None  None  None      None
# 0     고추/피망/파프리카   None  None  None      None
# 0            곡물차   None  None  None      None
# 0            과일류   None  None  None      None
# 0         국내산 돈육   None  None  None      None
# 0           굴 생물   None  None  None      None
# 0   기능성 아이케어 화장품   None  None  None      None
# 0     기능성 화장품 세트   None  None  None      None
# 0      기초 화장용 로션   None  None  None      None
# 0     기초 화장용 미스트   None  None  None      None
# 0      기초 화장용 크림   None  None  None      None
# 0         기타 주스류   None  None  None      None
# 0            김치류   None  None  None      None
# 0        난방용 열풍기   None  None  None      None
# 0          남성 로션   None  None  None      None
# 0         남성 선케어   None  None  None      None
# 0          남성 세트   None  None  None      None
# 0         남성 쉐이빙   None  None  None      None
# 0          느타리버섯   None  None  None      None
# 0        다이어트보조식   None  None  None      None
# 0   다이어트용 헬스보충식품   None  None  None      None
# 0         대게/킹크랩   None  None  None      None
# 0          데오드란트   None  None  None      None
# 0           둥굴레차   None  None  None      None
# 0    딸기/복분자/블루베리   None  None  None      None
# 0           딸기우유   None  None  None      None
# 0          라디에이터   None  None  None      None
# 0      루테인/눈 영양제   None  None  None      None
# 0          마늘/생강   None  None  None      None
# 0       메이크업 브러쉬   None  None  None      None
# 0          명태/동태   None  None  None      None
# 0            무김치   None  None  None      None
# 0            물김치   None  None  None      None
# 0            미나리   None  None  None      None
# 0      미숫가루/곡물가루   None  None  None      None
# 0        밀크티/티라떼   None  None  None      None
# 0         바디 보습제   None  None  None      None
# 0         바디 클렌져   None  None  None      None
# 0      바디케어용 땀패드   None  None  None      None
# 0      바디케어용 제모제   None  None  None      None
# 0           배추김치   None  None  None      None
# 0        벽걸이 에어컨   None  None  None      None
# 0       벽걸이형 선풍기   None  None  None      None
# 0            보리차   None  None  None      None
# 0        복합식 가습기   None  None  None      None
# 0             부추   None  None  None      None
# 0          뷰티 타투   None  None  None      None
# 0     뷰티용 면봉/귀이개   None  None  None      None
# 0       브로콜리/셀러리   None  None  None      None
# 0            비타민   None  None  None      None
# 0          새송이버섯   None  None  None      None
# 0     색조 메이크업 립밤   None  None  None      None
# 0    색조 메이크업 립틴트   None  None  None      None
# 0  색조 메이크업 아이섀도우   None  None   공적분      None
# 0            선로션   None  None  None      None
# 0          선스프레이   None  None  None      None
# 0        선케어용 선밤   None  None  None      None
# 0           선파우더   None  None  None      None
# 0         소고기 육회   None  None  None      None
# 0            시금치   None  None  None      None
# 0            쌈채소   None  None  None      None
# 0           아이스티   None  None  None      None
# 0           애프터선   None  None  None      None
# 0         야채/호박즙   None  None  None      None
# 0        양배추/양상추   None  None  None      None
# 0         어린이 음료   None  None  None      None
# 0         어린이영양제   None  None  None      None
# 0       어린잎/새싹채소   None  None  None      None
# 0        업소용 선풍기   None  None  None      None
# 0           에어워셔   None  None  None      None
# 0        에어컨 리모컨   None  None  None      None
# 0  오메가3/스쿠알렌 영양제   None  None  None      None
# 0          오이/가지   None  None  None      None
# 0           온수매트   None  None  None      None
# 0           온열매트   None  None  None      None
# 0            온풍기   None  None  None      None
# 0        요거트/발효유   None  None  None      None
# 0           원두커피   None  None  None      None
# 0            유자차   None  None  None      None
# 0            율무차   None  None  None      None
# 0          음용 식초   None  None  None      None
# 0        이동형 에어컨   None  None  None      None
# 0            입욕제   None   공적분   공적분      None
# 0        자연식 가습기   None  None  None      None
# 0         잡곡 씨드류   None  None  None      None
# 0             장어   None  None  None      None
# 0        저/무지방우유   None  None  None      None
# 0          전기온수기   None  None  None      None
# 0           전기장판   None  None  None      None
# 0            전통차   None  None  None      None
# 0             조개   None  None  None      None
# 0            주꾸미   None  None  None      None
# 0       참외/메론/수박   None  None  None      None
# 0       초음파식 가습기   None  None  None      None
# 0           초코우유   None  None  None      None
# 0          카페트매트   None  None  None      None
# 0      칼슘/철분 영양제   None  None  None      None
# 0       캡슐/POD커피   None  None  None      None
# 0            컨벡터   None  None  None      None
# 0        코코아/핫초코   None  None  None      None
# 0    콜라겐/코큐텐 영양제   None  None  None      None
# 0         클렌징 로션   None  None  None      None
# 0         클렌징 티슈   None  None  None      None
# 0     탁상/USB 선풍기   None  None  None      None
# 0            탄산수   None  None  None      None
# 0           탄산음료   None  None  None      None
# 0            토마토   None  None  None      None
# 0           파/양파   None  None  None      None
# 0            파김치   None  None  None      None
# 0       포도/거봉/체리   None  None  None      None
# 0        프로바이오틱스   None  None  None      None
# 0     프로폴리스/로얄젤리   None  None  None      None
# 0           해초류    None  None  None      None
# 0       핸드워시/스크럽   None  None  None      None
# 0           핸드크림   None  None  None      None
# 0            허브차   None   공적분  None      None
# 0         헤어 브러쉬   None  None  None      None
# 0     헤어스타일링용 흑채   None  None  None      None
# 0         헤어스프레이   None  None  None      None
# 0          헤어에센스   None  None  None      None
# 0             호박   None  None  None      None
# 0             홍차   None  None  None      None
# 0            환자식   None  None  None      None
# 0           황토매트   None  None  None      None
# 0        휴대용 선풍기   None  None  None      None
# 0             히터   None  None  None      None

# %% [markdown]
# #### VECM & Granger Causality Test

# %%
ush_vecm_res = pd.DataFrame()

for w_var in st_weather:
    for sm_cat in ush_item:
        # 공적분 관계가 유의할 때, 그래인저 인과관계 분석
        if (ush_co_res.loc[ush_co_res.sm_cat==sm_cat, w_var] == '공적분').values: 
            result = VECM_granger(ush, weather, sm_cat, w_var)
        else:
            result = pd.DataFrame([{'sm_cat':sm_cat, 'weather':w_var, 'granger_reject':'None'}])
        ush_vecm_res = pd.concat([ush_vecm_res, result], axis=0)

# %%
for w in st_weather:
    print('===== Granger Causality : {} ====='.format(w))
    print(ush_vecm_res.loc[ush_vecm_res.weather==w, 'granger_reject'].value_counts())
    print(' ')
# Out:
# ===== Granger Causality : avg_ws =====
# None    134
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : PM10 =====
# None         132
# causality      2
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : PM25 =====
# None         133
# causality      1
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : sum_ss_hr =====
# None    134
# Name: granger_reject, dtype: int64

# %%
# 인과관계가 존재하는 경우
ush_vecm_pivot = pd.pivot_table(ush_vecm_res, index='sm_cat', values='granger_reject', columns='weather', aggfunc='first')
ush_vecm_pivot
# Out:
# weather             PM10       PM25 avg_ws sum_ss_hr
# sm_cat
# 가열식 가습기             None       None   None      None
# 갈비/찜/바비큐용 돈육        None       None   None      None
# 감귤/한라봉/오렌지          None       None   None      None
# 감자                  None       None   None      None
# 건대추                 None       None   None      None
# 건어물 진미채             None       None   None      None
# 건포도                 None       None   None      None
# 게장류                 None       None   None      None
# 견과류 밤               None       None   None      None
# 고추/피망/파프리카          None       None   None      None
# 곡물차                 None       None   None      None
# 과일류                 None       None   None      None
# 국내산 돈육              None       None   None      None
# 굴 생물                None       None   None      None
# 기능성 아이케어 화장품        None       None   None      None
# 기능성 화장품 세트          None       None   None      None
# 기초 화장용 로션           None       None   None      None
# 기초 화장용 미스트          None       None   None      None
# 기초 화장용 크림           None       None   None      None
# 기타 주스류              None       None   None      None
# 김치류                 None       None   None      None
# 난방용 열풍기             None       None   None      None
# 남성 로션               None       None   None      None
# 남성 선케어              None       None   None      None
# 남성 세트               None       None   None      None
# 남성 쉐이빙              None       None   None      None
# 느타리버섯               None       None   None      None
# 다이어트보조식             None       None   None      None
# 다이어트용 헬스보충식품        None       None   None      None
# 대게/킹크랩              None       None   None      None
# 데오드란트               None       None   None      None
# 둥굴레차                None       None   None      None
# 딸기/복분자/블루베리         None       None   None      None
# 딸기우유                None       None   None      None
# 라디에이터               None       None   None      None
# 루테인/눈 영양제           None       None   None      None
# 마늘/생강               None       None   None      None
# 메이크업 브러쉬            None       None   None      None
# 명태/동태               None       None   None      None
# 무김치                 None       None   None      None
# 물김치                 None       None   None      None
# 미나리                 None       None   None      None
# 미숫가루/곡물가루           None       None   None      None
# 밀크티/티라떼             None       None   None      None
# 바디 보습제              None       None   None      None
# 바디 클렌져              None       None   None      None
# 바디케어용 땀패드           None       None   None      None
# 바디케어용 제모제           None       None   None      None
# 배추김치                None       None   None      None
# 벽걸이 에어컨             None       None   None      None
# 벽걸이형 선풍기            None       None   None      None
# 보리차                 None       None   None      None
# 복합식 가습기             None       None   None      None
# 부추                  None       None   None      None
# 뷰티 타투               None       None   None      None
# 뷰티용 면봉/귀이개          None       None   None      None
# 브로콜리/셀러리            None       None   None      None
# 비타민                 None       None   None      None
# 새송이버섯               None       None   None      None
# 색조 메이크업 립밤          None       None   None      None
# 색조 메이크업 립틴트         None       None   None      None
# 색조 메이크업 아이섀도우       None       None   None      None
# 선로션                 None       None   None      None
# 선스프레이               None       None   None      None
# 선케어용 선밤             None       None   None      None
# 선파우더                None       None   None      None
# 소고기 육회              None       None   None      None
# 시금치                 None       None   None      None
# 쌈채소                 None       None   None      None
# 아이스티                None       None   None      None
# 애프터선                None       None   None      None
# 야채/호박즙              None       None   None      None
# 양배추/양상추             None       None   None      None
# 어린이 음료              None       None   None      None
# 어린이영양제              None       None   None      None
# 어린잎/새싹채소            None       None   None      None
# 업소용 선풍기             None       None   None      None
# 에어워셔                None       None   None      None
# 에어컨 리모컨             None       None   None      None
# 오메가3/스쿠알렌 영양제       None       None   None      None
# 오이/가지               None       None   None      None
# 온수매트                None       None   None      None
# 온열매트                None       None   None      None
# 온풍기                 None       None   None      None
# 요거트/발효유             None       None   None      None
# 원두커피                None       None   None      None
# 유자차                 None       None   None      None
# 율무차                 None       None   None      None
# 음용 식초               None       None   None      None
# 이동형 에어컨             None       None   None      None
# 입욕제            causality  causality   None      None
# 자연식 가습기             None       None   None      None
# 잡곡 씨드류              None       None   None      None
# 장어                  None       None   None      None
# 저/무지방우유             None       None   None      None
# 전기온수기               None       None   None      None
# 전기장판                None       None   None      None
# 전통차                 None       None   None      None
# 조개                  None       None   None      None
# 주꾸미                 None       None   None      None
# 참외/메론/수박            None       None   None      None
# 초음파식 가습기            None       None   None      None
# 초코우유                None       None   None      None
# 카페트매트               None       None   None      None
# 칼슘/철분 영양제           None       None   None      None
# 캡슐/POD커피            None       None   None      None
# 컨벡터                 None       None   None      None
# 코코아/핫초코             None       None   None      None
# 콜라겐/코큐텐 영양제         None       None   None      None
# 클렌징 로션              None       None   None      None
# 클렌징 티슈              None       None   None      None
# 탁상/USB 선풍기          None       None   None      None
# 탄산수                 None       None   None      None
# 탄산음료                None       None   None      None
# 토마토                 None       None   None      None
# 파/양파                None       None   None      None
# 파김치                 None       None   None      None
# 포도/거봉/체리            None       None   None      None
# 프로바이오틱스             None       None   None      None
# 프로폴리스/로얄젤리          None       None   None      None
# 해초류                 None       None   None      None
# 핸드워시/스크럽            None       None   None      None
# 핸드크림                None       None   None      None
# 허브차            causality       None   None      None
# 헤어 브러쉬              None       None   None      None
# 헤어스타일링용 흑채          None       None   None      None
# 헤어스프레이              None       None   None      None
# 헤어에센스               None       None   None      None
# 호박                  None       None   None      None
# 홍차                  None       None   None      None
# 환자식                 None       None   None      None
# 황토매트                None       None   None      None
# 휴대용 선풍기             None       None   None      None
# 히터                  None       None   None      None

# %% [markdown]
# ### 1-2-2. 비정상 상품과 비정상 날씨

# %% [markdown]
# #### 공적분 검정

# %%
ush_co_res2 = pd.DataFrame()
for i in range(len(nst_weather)):
    w_sample = weather[nst_weather[i]]
    res = pd.DataFrame()
    for sm_cat in ush_item:
        res = pd.concat([res, co_test(ush, weather, sm_cat, nst_weather[i])], axis=0)
    if i == 0:
        ush_co_res2 = pd.concat([ush_co_res2, res], axis=1)
    else:
        ush_co_res2 = pd.concat([ush_co_res2, res.drop(['sm_cat'], axis=1)], axis=1)

# %%
ush_co_res2
# Out:
#           sm_cat avg_ta max_ta min_ta hm_max max_pa
# 0        가열식 가습기   None   None   None   None   None
# 0   갈비/찜/바비큐용 돈육   None   None   None   None    공적분
# 0     감귤/한라봉/오렌지    공적분    공적분   None   None   None
# 0             감자   None   None   None   None   None
# 0            건대추   None   None   None   None   None
# 0        건어물 진미채   None   None   None   None   None
# 0            건포도    공적분   None    공적분   None   None
# 0            게장류   None   None   None   None   None
# 0          견과류 밤   None   None   None   None   None
# 0     고추/피망/파프리카   None   None   None   None   None
# 0            곡물차   None   None   None   None   None
# 0            과일류    공적분    공적분    공적분   None   None
# 0         국내산 돈육   None   None   None   None   None
# 0           굴 생물   None   None   None   None   None
# 0   기능성 아이케어 화장품    공적분    공적분    공적분   None   None
# 0     기능성 화장품 세트   None   None   None   None   None
# 0      기초 화장용 로션    공적분    공적분    공적분   None   None
# 0     기초 화장용 미스트    공적분    공적분    공적분   None   None
# 0      기초 화장용 크림   None   None   None   None   None
# 0         기타 주스류   None   None   None   None   None
# 0            김치류   None   None   None   None   None
# 0        난방용 열풍기   None   None   None    공적분   None
# 0          남성 로션   None   None   None   None   None
# 0         남성 선케어   None   None   None   None   None
# 0          남성 세트   None   None   None   None   None
# 0         남성 쉐이빙   None   None   None   None   None
# 0          느타리버섯   None   None   None   None   None
# 0        다이어트보조식   None   None   None   None   None
# 0   다이어트용 헬스보충식품   None   None   None   None   None
# 0         대게/킹크랩   None   None   None   None   None
# 0          데오드란트   None   None   None   None   None
# 0           둥굴레차   None   None   None   None   None
# 0    딸기/복분자/블루베리   None   None   None   None   None
# 0           딸기우유   None   None   None   None   None
# 0          라디에이터   None   None   None   None   None
# 0      루테인/눈 영양제   None   None   None   None   None
# 0          마늘/생강   None   None   None   None   None
# 0       메이크업 브러쉬   None   None   None   None   None
# 0          명태/동태   None   None   None   None    공적분
# 0            무김치   None   None   None   None   None
# 0            물김치   None   None   None   None   None
# 0            미나리   None   None   None   None   None
# 0      미숫가루/곡물가루   None   None    공적분   None   None
# 0        밀크티/티라떼   None   None   None   None   None
# 0         바디 보습제   None   None   None   None   None
# 0         바디 클렌져   None   None   None   None   None
# 0      바디케어용 땀패드   None   None   None   None   None
# 0      바디케어용 제모제   None   None   None   None   None
# 0           배추김치   None   None   None   None   None
# 0        벽걸이 에어컨    공적분    공적분    공적분   None   None
# 0       벽걸이형 선풍기   None   None   None   None   None
# 0            보리차   None   None   None   None   None
# 0        복합식 가습기   None   None   None   None   None
# 0             부추   None   None   None   None   None
# 0          뷰티 타투   None   None   None   None   None
# 0     뷰티용 면봉/귀이개   None   None   None    공적분    공적분
# 0       브로콜리/셀러리   None   None   None   None   None
# 0            비타민   None   None   None   None   None
# 0          새송이버섯   None   None   None   None   None
# 0     색조 메이크업 립밤   None   None   None   None   None
# 0    색조 메이크업 립틴트   None   None   None   None   None
# 0  색조 메이크업 아이섀도우    공적분    공적분    공적분    공적분   None
# 0            선로션   None   None   None   None   None
# 0          선스프레이   None   None   None   None   None
# 0        선케어용 선밤   None   None   None   None   None
# 0           선파우더   None   None   None   None   None
# 0         소고기 육회   None   None   None   None   None
# 0            시금치   None   None   None   None   None
# 0            쌈채소   None   None   None   None   None
# 0           아이스티   None   None   None   None   None
# 0           애프터선   None   None   None   None   None
# 0         야채/호박즙   None   None   None   None   None
# 0        양배추/양상추   None   None   None   None   None
# 0         어린이 음료   None   None   None   None   None
# 0         어린이영양제   None   None   None   None   None
# 0       어린잎/새싹채소   None   None   None   None   None
# 0        업소용 선풍기    공적분    공적분    공적분   None   None
# 0           에어워셔    공적분   None    공적분   None   None
# 0        에어컨 리모컨    공적분    공적분    공적분   None   None
# 0  오메가3/스쿠알렌 영양제   None   None   None   None   None
# 0          오이/가지   None   None   None   None   None
# 0           온수매트   None   None   None   None   None
# 0           온열매트   None   None   None   None   None
# 0            온풍기   None   None   None   None   None
# 0        요거트/발효유   None   None   None   None   None
# 0           원두커피   None   None   None   None   None
# 0            유자차   None   None   None   None   None
# 0            율무차   None   None   None   None   None
# 0          음용 식초    공적분    공적분    공적분   None   None
# 0        이동형 에어컨    공적분    공적분    공적분   None   None
# 0            입욕제   None    공적분   None    공적분   None
# 0        자연식 가습기   None   None   None   None   None
# 0         잡곡 씨드류   None   None   None   None   None
# 0             장어   None   None   None   None   None
# 0        저/무지방우유   None   None   None   None   None
# 0          전기온수기   None   None   None   None   None
# 0           전기장판   None   None   None   None   None
# 0            전통차   None   None   None   None    공적분
# 0             조개   None   None   None   None   None
# 0            주꾸미   None   None   None   None   None
# 0       참외/메론/수박   None   None   None   None   None
# 0       초음파식 가습기   None   None   None   None   None
# 0           초코우유   None   None   None   None    공적분
# 0          카페트매트   None   None   None   None   None
# 0      칼슘/철분 영양제   None   None   None   None   None
# 0       캡슐/POD커피   None   None   None   None   None
# 0            컨벡터   None   None   None   None   None
# 0        코코아/핫초코   None   None   None   None   None
# 0    콜라겐/코큐텐 영양제   None   None   None   None   None
# 0         클렌징 로션   None   None   None   None   None
# 0         클렌징 티슈   None   None   None   None   None
# 0     탁상/USB 선풍기   None   None   None   None   None
# 0            탄산수   None   None   None   None   None
# 0           탄산음료   None   None   None   None    공적분
# 0            토마토   None   None   None   None   None
# 0           파/양파   None   None   None   None   None
# 0            파김치   None   None   None   None   None
# 0       포도/거봉/체리   None   None   None   None   None
# 0        프로바이오틱스   None   None   None   None   None
# 0     프로폴리스/로얄젤리   None   None   None   None   None
# 0           해초류     공적분    공적분    공적분   None   None
# 0       핸드워시/스크럽   None   None   None   None   None
# 0           핸드크림   None   None   None   None   None
# 0            허브차   None   None   None   None    공적분
# 0         헤어 브러쉬   None   None   None   None   None
# 0     헤어스타일링용 흑채   None   None   None   None   None
# 0         헤어스프레이   None   None   None   None   None
# 0          헤어에센스   None   None   None   None   None
# 0             호박   None   None   None   None   None
# 0             홍차    공적분    공적분    공적분   None   None
# 0            환자식   None   None   None   None   None
# 0           황토매트   None   None   None   None   None
# 0        휴대용 선풍기    공적분    공적분   None   None   None
# 0             히터   None   None   None   None   None

# %% [markdown]
# #### VECM & Granger Causality Test

# %%
warnings.filterwarnings('ignore')
ush_vecm_res2 = pd.DataFrame()

for w_var in nst_weather:
    for sm_cat in ush_item:
        # 공적분 관계가 유의할 때, 그래인저 인과관계 분석
        if (ush_co_res2.loc[ush_co_res2.sm_cat==sm_cat, w_var] == '공적분').values: 
            result = VECM_granger(ush, weather, sm_cat, w_var)
        else:
            result = pd.DataFrame([{'sm_cat':sm_cat, 'weather':w_var, 'granger_reject':'None'}])
        ush_vecm_res2 = pd.concat([ush_vecm_res2, result], axis=0)

# %%
for w in nst_weather:
    print('===== Granger Causality : {} ====='.format(w))
    print(ush_vecm_res2.loc[ush_vecm_res2.weather==w, 'granger_reject'].value_counts())
    print(' ')
# Out:
# ===== Granger Causality : avg_ta =====
# None         131
# causality      3
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : max_ta =====
# None         131
# causality      3
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : min_ta =====
# None    134
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : hm_max =====
# None         133
# causality      1
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : max_pa =====
# None    134
# Name: granger_reject, dtype: int64

# %%
ush_vecm_pivot2 = pd.pivot_table(ush_vecm_res2, index='sm_cat', values='granger_reject', columns='weather', aggfunc='first')
ush_vecm_pivot2
# Out:
# weather           avg_ta     hm_max max_pa     max_ta min_ta
# sm_cat
# 가열식 가습기             None       None   None       None   None
# 갈비/찜/바비큐용 돈육        None       None   None       None   None
# 감귤/한라봉/오렌지          None       None   None       None   None
# 감자                  None       None   None       None   None
# 건대추                 None       None   None       None   None
# 건어물 진미채             None       None   None       None   None
# 건포도                 None       None   None       None   None
# 게장류                 None       None   None       None   None
# 견과류 밤               None       None   None       None   None
# 고추/피망/파프리카          None       None   None       None   None
# 곡물차                 None       None   None       None   None
# 과일류                 None       None   None       None   None
# 국내산 돈육              None       None   None       None   None
# 굴 생물                None       None   None       None   None
# 기능성 아이케어 화장품        None       None   None       None   None
# 기능성 화장품 세트          None       None   None       None   None
# 기초 화장용 로션           None       None   None       None   None
# 기초 화장용 미스트          None       None   None       None   None
# 기초 화장용 크림           None       None   None       None   None
# 기타 주스류              None       None   None       None   None
# 김치류                 None       None   None       None   None
# 난방용 열풍기             None       None   None       None   None
# 남성 로션               None       None   None       None   None
# 남성 선케어              None       None   None       None   None
# 남성 세트               None       None   None       None   None
# 남성 쉐이빙              None       None   None       None   None
# 느타리버섯               None       None   None       None   None
# 다이어트보조식             None       None   None       None   None
# 다이어트용 헬스보충식품        None       None   None       None   None
# 대게/킹크랩              None       None   None       None   None
# 데오드란트               None       None   None       None   None
# 둥굴레차                None       None   None       None   None
# 딸기/복분자/블루베리         None       None   None       None   None
# 딸기우유                None       None   None       None   None
# 라디에이터               None       None   None       None   None
# 루테인/눈 영양제           None       None   None       None   None
# 마늘/생강               None       None   None       None   None
# 메이크업 브러쉬            None       None   None       None   None
# 명태/동태               None       None   None       None   None
# 무김치                 None       None   None       None   None
# 물김치                 None       None   None       None   None
# 미나리                 None       None   None       None   None
# 미숫가루/곡물가루           None       None   None       None   None
# 밀크티/티라떼             None       None   None       None   None
# 바디 보습제              None       None   None       None   None
# 바디 클렌져              None       None   None       None   None
# 바디케어용 땀패드           None       None   None       None   None
# 바디케어용 제모제           None       None   None       None   None
# 배추김치                None       None   None       None   None
# 벽걸이 에어컨        causality       None   None  causality   None
# 벽걸이형 선풍기            None       None   None       None   None
# 보리차                 None       None   None       None   None
# 복합식 가습기             None       None   None       None   None
# 부추                  None       None   None       None   None
# 뷰티 타투               None       None   None       None   None
# 뷰티용 면봉/귀이개          None       None   None       None   None
# 브로콜리/셀러리            None       None   None       None   None
# 비타민                 None       None   None       None   None
# 새송이버섯               None       None   None       None   None
# 색조 메이크업 립밤          None       None   None       None   None
# 색조 메이크업 립틴트         None       None   None       None   None
# 색조 메이크업 아이섀도우       None       None   None       None   None
# 선로션                 None       None   None       None   None
# 선스프레이               None       None   None       None   None
# 선케어용 선밤             None       None   None       None   None
# 선파우더                None       None   None       None   None
# 소고기 육회              None       None   None       None   None
# 시금치                 None       None   None       None   None
# 쌈채소                 None       None   None       None   None
# 아이스티                None       None   None       None   None
# 애프터선                None       None   None       None   None
# 야채/호박즙              None       None   None       None   None
# 양배추/양상추             None       None   None       None   None
# 어린이 음료              None       None   None       None   None
# 어린이영양제              None       None   None       None   None
# 어린잎/새싹채소            None       None   None       None   None
# 업소용 선풍기             None       None   None       None   None
# 에어워셔                None       None   None       None   None
# 에어컨 리모컨        causality       None   None  causality   None
# 오메가3/스쿠알렌 영양제       None       None   None       None   None
# 오이/가지               None       None   None       None   None
# 온수매트                None       None   None       None   None
# 온열매트                None       None   None       None   None
# 온풍기                 None       None   None       None   None
# 요거트/발효유             None       None   None       None   None
# 원두커피                None       None   None       None   None
# 유자차                 None       None   None       None   None
# 율무차                 None       None   None       None   None
# 음용 식초          causality       None   None  causality   None
# 이동형 에어컨             None       None   None       None   None
# 입욕제                 None  causality   None       None   None
# 자연식 가습기             None       None   None       None   None
# 잡곡 씨드류              None       None   None       None   None
# 장어                  None       None   None       None   None
# 저/무지방우유             None       None   None       None   None
# 전기온수기               None       None   None       None   None
# 전기장판                None       None   None       None   None
# 전통차                 None       None   None       None   None
# 조개                  None       None   None       None   None
# 주꾸미                 None       None   None       None   None
# 참외/메론/수박            None       None   None       None   None
# 초음파식 가습기            None       None   None       None   None
# 초코우유                None       None   None       None   None
# 카페트매트               None       None   None       None   None
# 칼슘/철분 영양제           None       None   None       None   None
# 캡슐/POD커피            None       None   None       None   None
# 컨벡터                 None       None   None       None   None
# 코코아/핫초코             None       None   None       None   None
# 콜라겐/코큐텐 영양제         None       None   None       None   None
# 클렌징 로션              None       None   None       None   None
# 클렌징 티슈              None       None   None       None   None
# 탁상/USB 선풍기          None       None   None       None   None
# 탄산수                 None       None   None       None   None
# 탄산음료                None       None   None       None   None
# 토마토                 None       None   None       None   None
# 파/양파                None       None   None       None   None
# 파김치                 None       None   None       None   None
# 포도/거봉/체리            None       None   None       None   None
# 프로바이오틱스             None       None   None       None   None
# 프로폴리스/로얄젤리          None       None   None       None   None
# 해초류                 None       None   None       None   None
# 핸드워시/스크럽            None       None   None       None   None
# 핸드크림                None       None   None       None   None
# 허브차                 None       None   None       None   None
# 헤어 브러쉬              None       None   None       None   None
# 헤어스타일링용 흑채          None       None   None       None   None
# 헤어스프레이              None       None   None       None   None
# 헤어에센스               None       None   None       None   None
# 호박                  None       None   None       None   None
# 홍차                  None       None   None       None   None
# 환자식                 None       None   None       None   None
# 황토매트                None       None   None       None   None
# 휴대용 선풍기             None       None   None       None   None
# 히터                  None       None   None       None   None

# %% [markdown]
# ### 1-2-3. 비정상 상품 인과관계 (with VECM)

# %%
ush_granger1 = pd.concat([ush_vecm_pivot, ush_vecm_pivot2], axis=1).reset_index()
ush_granger1['total'] = np.sum(ush_granger1.iloc[:,1:]=='causality', axis=1) # 인과관계가 있는 feature 개수
ush_granger1 = ush_granger1.loc[ush_granger1.total>0,:]

ush_granger1 # 5개 실화
# Out:
# weather   sm_cat       PM10       PM25 avg_ws  ... max_pa     max_ta min_ta total
# 49       벽걸이 에어컨       None       None   None  ...   None  causality   None     2
# 78       에어컨 리모컨       None       None   None  ...   None  causality   None     2
# 88         음용 식초       None       None   None  ...   None  causality   None     2
# 90           입욕제  causality  causality   None  ...   None       None   None     3
# 123          허브차  causality       None   None  ...   None       None   None     1
#
# [5 rows x 11 columns]

# %% [markdown]
# ## 1-3. 비정상 상품 (with VAR)

# %%
ush_item_var = ush_item.copy()
for sm_cat in ush_granger.sm_cat:
    ush_item_var.remove(sm_cat) # VECM을 통해 인과관계를 도출할 수 없었던 sm_cat

# %% [markdown]
# ### 1-3-1. 비정상 상품과 정상 날씨

# %%
ush_var_res = pd.DataFrame()

for w in st_weather:
    for sm_cat in ush_item_var:
        if (adf_test(ush, sm_cat).test_res=='정상').values:
            result = VAR_granger(ush, weather, sm_cat, w)
        elif (adf_test(weather.diff(1).fillna(0), w).test_res=='정상').values: # 원데이터가 정상이 아니면 1차차분. 1차차분 시 정상이면 VAR 적합
            weather_diff = weather.diff(1).fillna(0)
            result = VAR_granger(ush, weather_diff, sm_cat, w)
        else:
            result = pd.DataFrame([{'sm_cat':sm_cat, 'weather':w, 'var_lag':lag, 'granger_reject':'None'}])
        ush_var_res = pd.concat([ush_var_res, result], axis=0)

# %%
for w in st_weather:
    print('===== Granger Causality : {} ====='.format(w))
    print(ush_var_res.loc[ush_var_res.weather==w, 'granger_reject'].value_counts())
    print(' ')
# Out:
# ===== Granger Causality : avg_ws =====
# None         116
# causality     13
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : PM10 =====
# None         115
# causality     14
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : PM25 =====
# None         119
# causality     10
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : sum_ss_hr =====
# None         119
# causality     10
# Name: granger_reject, dtype: int64

# %%
ush_var_pivot = pd.pivot_table(ush_var_res, index='sm_cat', values='granger_reject', columns='weather', aggfunc='first')
ush_var_pivot
# Out:
# weather             PM10       PM25     avg_ws  sum_ss_hr
# sm_cat
# 가열식 가습기        causality  causality  causality       None
# 갈비/찜/바비큐용 돈육        None       None       None       None
# 감귤/한라봉/오렌지          None       None       None       None
# 감자                  None       None       None       None
# 건대추                 None       None  causality       None
# 건어물 진미채        causality       None       None       None
# 건포도                 None       None       None       None
# 게장류                 None       None       None       None
# 견과류 밤               None  causality       None       None
# 고추/피망/파프리카          None       None       None       None
# 곡물차                 None       None       None  causality
# 과일류                 None       None       None       None
# 국내산 돈육              None       None       None       None
# 굴 생물                None       None       None       None
# 기능성 아이케어 화장품        None       None       None       None
# 기능성 화장품 세트          None       None       None       None
# 기초 화장용 로션           None       None       None       None
# 기초 화장용 미스트          None       None       None       None
# 기초 화장용 크림           None       None       None  causality
# 기타 주스류              None       None       None       None
# 김치류                 None       None       None       None
# 난방용 열풍기             None       None       None       None
# 남성 로션               None       None       None       None
# 남성 선케어              None       None       None       None
# 남성 세트               None       None       None       None
# 남성 쉐이빙              None       None       None       None
# 느타리버섯          causality  causality       None       None
# 다이어트보조식             None       None       None       None
# 다이어트용 헬스보충식품        None       None       None       None
# 대게/킹크랩              None       None       None       None
# 데오드란트               None       None       None       None
# 둥굴레차           causality  causality       None       None
# 딸기/복분자/블루베리         None       None       None       None
# 딸기우유                None       None       None       None
# 라디에이터          causality  causality  causality       None
# 루테인/눈 영양제           None       None       None       None
# 마늘/생강               None       None       None       None
# 메이크업 브러쉬            None       None       None       None
# 명태/동태               None       None  causality       None
# 무김치                 None       None       None       None
# 물김치                 None       None       None       None
# 미나리                 None       None       None       None
# 미숫가루/곡물가루           None       None       None       None
# 밀크티/티라떼             None       None       None       None
# 바디 보습제              None       None       None       None
# 바디 클렌져              None       None       None  causality
# 바디케어용 땀패드           None       None       None       None
# 바디케어용 제모제           None       None       None       None
# 배추김치                None       None       None       None
# 벽걸이형 선풍기            None       None       None       None
# 보리차                 None       None       None       None
# 복합식 가습기        causality  causality       None       None
# 부추                  None       None       None  causality
# 뷰티 타투               None       None       None       None
# 뷰티용 면봉/귀이개          None       None       None       None
# 브로콜리/셀러리            None       None       None       None
# 비타민                 None       None       None       None
# 새송이버섯               None       None       None       None
# 색조 메이크업 립밤     causality  causality       None       None
# 색조 메이크업 립틴트         None       None       None       None
# 색조 메이크업 아이섀도우       None       None       None       None
# 선로션                 None       None       None       None
# 선스프레이               None       None       None  causality
# 선케어용 선밤             None       None       None  causality
# 선파우더                None       None       None       None
# 소고기 육회              None       None       None  causality
# 시금치                 None       None       None       None
# 쌈채소                 None       None       None       None
# 아이스티                None       None       None       None
# 애프터선                None       None       None       None
# 야채/호박즙              None       None       None       None
# 양배추/양상추             None       None  causality       None
# 어린이 음료              None       None       None       None
# 어린이영양제              None       None       None       None
# 어린잎/새싹채소            None       None       None       None
# 업소용 선풍기             None       None       None       None
# 에어워셔           causality       None       None  causality
# 오메가3/스쿠알렌 영양제  causality       None       None       None
# 오이/가지               None       None       None       None
# 온수매트                None       None       None       None
# 온열매트                None       None       None       None
# 온풍기            causality  causality  causality       None
# 요거트/발효유             None       None       None       None
# 원두커피                None       None       None       None
# 유자차            causality       None       None       None
# 율무차                 None       None       None       None
# 이동형 에어컨             None       None       None       None
# 자연식 가습기             None       None       None       None
# 잡곡 씨드류              None  causality       None       None
# 장어                  None       None       None       None
# 저/무지방우유             None       None       None       None
# 전기온수기               None       None       None       None
# 전기장판                None       None       None       None
# 전통차                 None       None       None       None
# 조개                  None       None       None       None
# 주꾸미                 None       None       None       None
# 참외/메론/수박            None       None       None       None
# 초음파식 가습기       causality  causality  causality       None
# 초코우유                None       None       None       None
# 카페트매트               None       None  causality       None
# 칼슘/철분 영양제           None       None  causality       None
# 캡슐/POD커피            None       None       None       None
# 컨벡터            causality       None  causality       None
# 코코아/핫초코             None       None       None       None
# 콜라겐/코큐텐 영양제         None       None  causality       None
# 클렌징 로션              None       None       None       None
# 클렌징 티슈              None       None       None       None
# 탁상/USB 선풍기          None       None       None       None
# 탄산수                 None       None       None  causality
# 탄산음료                None       None       None       None
# 토마토                 None       None       None       None
# 파/양파                None       None       None  causality
# 파김치                 None       None  causality       None
# 포도/거봉/체리            None       None       None       None
# 프로바이오틱스             None       None       None       None
# 프로폴리스/로얄젤리          None       None       None       None
# 해초류                 None       None       None       None
# 핸드워시/스크럽            None       None       None       None
# 핸드크림                None       None       None       None
# 헤어 브러쉬              None       None       None       None
# 헤어스타일링용 흑채          None       None       None       None
# 헤어스프레이              None       None       None       None
# 헤어에센스               None       None       None       None
# 호박                  None       None       None       None
# 홍차                  None       None       None       None
# 환자식                 None       None       None       None
# 황토매트                None       None       None       None
# 휴대용 선풍기             None       None       None       None
# 히터             causality       None  causality       None

# %% [markdown]
# ### 1-3-2. 비정상 상품과 비정상 날씨

# %%
ush_var_res2 = pd.DataFrame()

for w in nst_weather:
    for sm_cat in ush_item_var:
        if (adf_test(ush, sm_cat).test_res=='정상').values:
            result = VAR_granger(ush, weather, sm_cat, w)
        elif (adf_test(weather.diff(1).fillna(0), w).test_res=='정상').values:
            weather_diff = weather.diff(1).fillna(0)
            result = VAR_granger(ush, weather_diff, sm_cat, w)
        else:
            result = pd.DataFrame([{'sm_cat':sm_cat, 'weather':w, 'var_lag':lag, 'granger_reject':'None'}])
        ush_var_res2 = pd.concat([ush_var_res2, result], axis=0)

# %%
for w in nst_weather:
    print('===== Granger Causality : {} ====='.format(w))
    print(ush_var_res2.loc[ush_var_res2.weather==w, 'granger_reject'].value_counts())
    print(' ')
# Out:
# ===== Granger Causality : avg_ta =====
# None         90
# causality    39
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : max_ta =====
# None         99
# causality    30
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : min_ta =====
# None         96
# causality    33
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : hm_max =====
# None         96
# causality    33
# Name: granger_reject, dtype: int64
#
# ===== Granger Causality : max_pa =====
# None         119
# causality     10
# Name: granger_reject, dtype: int64

# %%
ush_var_pivot2 = pd.pivot_table(ush_var_res2, index='sm_cat', values='granger_reject', columns='weather', aggfunc='first')
ush_var_pivot2
# Out:
# weather           avg_ta     hm_max     max_pa     max_ta     min_ta
# sm_cat
# 가열식 가습기        causality  causality       None  causality  causality
# 갈비/찜/바비큐용 돈육        None       None       None       None       None
# 감귤/한라봉/오렌지     causality  causality       None       None  causality
# 감자                  None       None       None       None       None
# 건대추                 None       None       None       None  causality
# 건어물 진미채             None       None       None       None       None
# 건포도                 None       None       None       None       None
# 게장류                 None       None       None       None       None
# 견과류 밤               None       None       None       None       None
# 고추/피망/파프리카          None       None       None       None       None
# 곡물차            causality       None       None       None  causality
# 과일류                 None       None       None       None       None
# 국내산 돈육              None       None       None       None       None
# 굴 생물                None       None       None       None       None
# 기능성 아이케어 화장품        None       None  causality       None       None
# 기능성 화장품 세트          None  causality  causality       None       None
# 기초 화장용 로션      causality  causality       None  causality  causality
# 기초 화장용 미스트          None  causality       None       None       None
# 기초 화장용 크림      causality  causality       None  causality  causality
# 기타 주스류              None       None  causality       None       None
# 김치류                 None       None       None       None       None
# 난방용 열풍기        causality       None       None       None       None
# 남성 로션               None       None       None       None       None
# 남성 선케어              None       None       None       None       None
# 남성 세트          causality  causality       None  causality  causality
# 남성 쉐이빙              None  causality       None       None       None
# 느타리버섯          causality       None       None  causality  causality
# 다이어트보조식             None       None       None       None       None
# 다이어트용 헬스보충식품        None       None       None       None       None
# 대게/킹크랩              None       None       None       None       None
# 데오드란트          causality       None       None  causality       None
# 둥굴레차                None  causality       None       None       None
# 딸기/복분자/블루베리    causality       None       None       None       None
# 딸기우유                None       None       None       None       None
# 라디에이터          causality  causality       None  causality  causality
# 루테인/눈 영양제           None  causality       None       None       None
# 마늘/생강               None       None       None       None       None
# 메이크업 브러쉬            None       None       None       None       None
# 명태/동태          causality  causality       None  causality  causality
# 무김치                 None       None       None       None       None
# 물김치                 None       None       None       None       None
# 미나리                 None       None       None       None       None
# 미숫가루/곡물가루           None       None       None       None       None
# 밀크티/티라떼             None       None       None       None       None
# 바디 보습제         causality  causality       None  causality  causality
# 바디 클렌져              None       None       None       None       None
# 바디케어용 땀패드      causality       None       None  causality       None
# 바디케어용 제모제           None       None       None  causality       None
# 배추김치                None       None       None       None       None
# 벽걸이형 선풍기            None       None       None       None       None
# 보리차                 None  causality  causality       None       None
# 복합식 가습기        causality  causality       None  causality  causality
# 부추                  None       None       None       None       None
# 뷰티 타투               None       None       None       None       None
# 뷰티용 면봉/귀이개          None       None       None       None       None
# 브로콜리/셀러리            None  causality       None       None       None
# 비타민            causality       None       None  causality  causality
# 새송이버섯               None       None       None       None       None
# 색조 메이크업 립밤     causality  causality       None  causality  causality
# 색조 메이크업 립틴트         None       None       None       None       None
# 색조 메이크업 아이섀도우       None       None       None       None  causality
# 선로션                 None       None       None       None       None
# 선스프레이               None       None       None       None       None
# 선케어용 선밤             None       None       None       None       None
# 선파우더                None       None       None       None       None
# 소고기 육회              None       None       None       None       None
# 시금치                 None       None       None       None       None
# 쌈채소            causality       None       None       None  causality
# 아이스티                None       None       None       None       None
# 애프터선                None       None       None       None       None
# 야채/호박즙              None       None       None       None       None
# 양배추/양상추             None  causality       None       None       None
# 어린이 음료              None       None       None       None       None
# 어린이영양제         causality       None       None  causality       None
# 어린잎/새싹채소            None       None       None       None       None
# 업소용 선풍기             None       None       None       None       None
# 에어워셔           causality  causality       None  causality  causality
# 오메가3/스쿠알렌 영양제       None       None       None       None       None
# 오이/가지               None       None       None       None       None
# 온수매트           causality       None       None  causality  causality
# 온열매트           causality  causality  causality  causality  causality
# 온풍기            causality  causality       None  causality  causality
# 요거트/발효유             None  causality       None       None       None
# 원두커피                None       None       None       None       None
# 유자차                 None  causality       None       None  causality
# 율무차            causality  causality  causality  causality  causality
# 이동형 에어컨             None       None       None       None       None
# 자연식 가습기        causality  causality       None  causality  causality
# 잡곡 씨드류              None       None       None       None       None
# 장어                  None       None  causality       None       None
# 저/무지방우유             None       None       None       None       None
# 전기온수기          causality  causality       None  causality  causality
# 전기장판           causality       None       None  causality  causality
# 전통차                 None       None       None       None       None
# 조개                  None       None       None       None       None
# 주꾸미                 None       None       None       None       None
# 참외/메론/수박            None       None       None       None       None
# 초음파식 가습기       causality  causality       None  causality  causality
# 초코우유           causality       None       None       None       None
# 카페트매트          causality       None       None       None  causality
# 칼슘/철분 영양제           None  causality       None       None       None
# 캡슐/POD커피       causality  causality       None       None  causality
# 컨벡터            causality       None       None  causality  causality
# 코코아/핫초코        causality       None       None  causality  causality
# 콜라겐/코큐텐 영양제    causality       None       None  causality       None
# 클렌징 로션         causality       None       None       None       None
# 클렌징 티슈              None       None       None       None       None
# 탁상/USB 선풍기     causality       None       None       None       None
# 탄산수                 None       None       None       None       None
# 탄산음료                None       None       None       None       None
# 토마토                 None       None       None       None       None
# 파/양파                None       None       None  causality       None
# 파김치                 None       None       None       None       None
# 포도/거봉/체리            None  causality       None       None       None
# 프로바이오틱스             None       None       None       None       None
# 프로폴리스/로얄젤리          None       None  causality       None       None
# 해초류                 None  causality       None       None       None
# 핸드워시/스크럽            None       None       None       None       None
# 핸드크림           causality       None  causality  causality  causality
# 헤어 브러쉬              None       None       None       None       None
# 헤어스타일링용 흑채          None       None       None       None       None
# 헤어스프레이              None       None       None       None       None
# 헤어에센스               None       None       None       None       None
# 호박                  None       None       None       None       None
# 홍차                  None       None       None       None       None
# 환자식                 None       None       None       None       None
# 황토매트           causality  causality       None       None  causality
# 휴대용 선풍기             None       None  causality       None       None
# 히터             causality  causality       None  causality  causality

# %% [markdown]
# ### 1-3-3. 비정상 상품 인과관계 (with VAR)

# %%
ush_granger2 = pd.concat([ush_var_pivot, ush_var_pivot2], axis=1).reset_index()
ush_granger2['total'] = np.sum(ush_granger2.iloc[:,1:]=='causality', axis=1) # 인과관계가 있는 feature 개수

ush_granger2
# Out:
# weather         sm_cat       PM10       PM25  ...     max_ta     min_ta total
# 0              가열식 가습기  causality  causality  ...  causality  causality     7
# 1         갈비/찜/바비큐용 돈육       None       None  ...       None       None     0
# 2           감귤/한라봉/오렌지       None       None  ...       None  causality     3
# 3                   감자       None       None  ...       None       None     0
# 4                  건대추       None       None  ...       None  causality     2
# 5              건어물 진미채  causality       None  ...       None       None     1
# 6                  건포도       None       None  ...       None       None     0
# 7                  게장류       None       None  ...       None       None     0
# 8                견과류 밤       None  causality  ...       None       None     1
# 9           고추/피망/파프리카       None       None  ...       None       None     0
# 10                 곡물차       None       None  ...       None  causality     3
# 11                 과일류       None       None  ...       None       None     0
# 12              국내산 돈육       None       None  ...       None       None     0
# 13                굴 생물       None       None  ...       None       None     0
# 14        기능성 아이케어 화장품       None       None  ...       None       None     1
# 15          기능성 화장품 세트       None       None  ...       None       None     2
# 16           기초 화장용 로션       None       None  ...  causality  causality     4
# 17          기초 화장용 미스트       None       None  ...       None       None     1
# 18           기초 화장용 크림       None       None  ...  causality  causality     5
# 19              기타 주스류       None       None  ...       None       None     1
# 20                 김치류       None       None  ...       None       None     0
# 21             난방용 열풍기       None       None  ...       None       None     1
# 22               남성 로션       None       None  ...       None       None     0
# 23              남성 선케어       None       None  ...       None       None     0
# 24               남성 세트       None       None  ...  causality  causality     4
# 25              남성 쉐이빙       None       None  ...       None       None     1
# 26               느타리버섯  causality  causality  ...  causality  causality     5
# 27             다이어트보조식       None       None  ...       None       None     0
# 28        다이어트용 헬스보충식품       None       None  ...       None       None     0
# 29              대게/킹크랩       None       None  ...       None       None     0
# 30               데오드란트       None       None  ...  causality       None     2
# 31                둥굴레차  causality  causality  ...       None       None     3
# 32         딸기/복분자/블루베리       None       None  ...       None       None     1
# 33                딸기우유       None       None  ...       None       None     0
# 34               라디에이터  causality  causality  ...  causality  causality     7
# 35           루테인/눈 영양제       None       None  ...       None       None     1
# 36               마늘/생강       None       None  ...       None       None     0
# 37            메이크업 브러쉬       None       None  ...       None       None     0
# 38               명태/동태       None       None  ...  causality  causality     5
# 39                 무김치       None       None  ...       None       None     0
# 40                 물김치       None       None  ...       None       None     0
# 41                 미나리       None       None  ...       None       None     0
# 42           미숫가루/곡물가루       None       None  ...       None       None     0
# 43             밀크티/티라떼       None       None  ...       None       None     0
# 44              바디 보습제       None       None  ...  causality  causality     4
# 45              바디 클렌져       None       None  ...       None       None     1
# 46           바디케어용 땀패드       None       None  ...  causality       None     2
# 47           바디케어용 제모제       None       None  ...  causality       None     1
# 48                배추김치       None       None  ...       None       None     0
# 49            벽걸이형 선풍기       None       None  ...       None       None     0
# 50                 보리차       None       None  ...       None       None     2
# 51             복합식 가습기  causality  causality  ...  causality  causality     6
# 52                  부추       None       None  ...       None       None     1
# 53               뷰티 타투       None       None  ...       None       None     0
# 54          뷰티용 면봉/귀이개       None       None  ...       None       None     0
# 55            브로콜리/셀러리       None       None  ...       None       None     1
# 56                 비타민       None       None  ...  causality  causality     3
# 57               새송이버섯       None       None  ...       None       None     0
# 58          색조 메이크업 립밤  causality  causality  ...  causality  causality     6
# 59         색조 메이크업 립틴트       None       None  ...       None       None     0
# 60       색조 메이크업 아이섀도우       None       None  ...       None  causality     1
# 61                 선로션       None       None  ...       None       None     0
# 62               선스프레이       None       None  ...       None       None     1
# 63             선케어용 선밤       None       None  ...       None       None     1
# 64                선파우더       None       None  ...       None       None     0
# 65              소고기 육회       None       None  ...       None       None     1
# 66                 시금치       None       None  ...       None       None     0
# 67                 쌈채소       None       None  ...       None  causality     2
# 68                아이스티       None       None  ...       None       None     0
# 69                애프터선       None       None  ...       None       None     0
# 70              야채/호박즙       None       None  ...       None       None     0
# 71             양배추/양상추       None       None  ...       None       None     2
# 72              어린이 음료       None       None  ...       None       None     0
# 73              어린이영양제       None       None  ...  causality       None     2
# 74            어린잎/새싹채소       None       None  ...       None       None     0
# 75             업소용 선풍기       None       None  ...       None       None     0
# 76                에어워셔  causality       None  ...  causality  causality     6
# 77       오메가3/스쿠알렌 영양제  causality       None  ...       None       None     1
# 78               오이/가지       None       None  ...       None       None     0
# 79                온수매트       None       None  ...  causality  causality     3
# 80                온열매트       None       None  ...  causality  causality     5
# 81                 온풍기  causality  causality  ...  causality  causality     7
# 82             요거트/발효유       None       None  ...       None       None     1
# 83                원두커피       None       None  ...       None       None     0
# 84                 유자차  causality       None  ...       None  causality     3
# 85                 율무차       None       None  ...  causality  causality     5
# 86             이동형 에어컨       None       None  ...       None       None     0
# 87             자연식 가습기       None       None  ...  causality  causality     4
# 88              잡곡 씨드류       None  causality  ...       None       None     1
# 89                  장어       None       None  ...       None       None     1
# 90             저/무지방우유       None       None  ...       None       None     0
# 91               전기온수기       None       None  ...  causality  causality     4
# 92                전기장판       None       None  ...  causality  causality     3
# 93                 전통차       None       None  ...       None       None     0
# 94                  조개       None       None  ...       None       None     0
# 95                 주꾸미       None       None  ...       None       None     0
# 96            참외/메론/수박       None       None  ...       None       None     0
# 97            초음파식 가습기  causality  causality  ...  causality  causality     7
# 98                초코우유       None       None  ...       None       None     1
# 99               카페트매트       None       None  ...       None  causality     3
# 100          칼슘/철분 영양제       None       None  ...       None       None     2
# 101           캡슐/POD커피       None       None  ...       None  causality     3
# 102                컨벡터  causality       None  ...  causality  causality     5
# 103            코코아/핫초코       None       None  ...  causality  causality     3
# 104        콜라겐/코큐텐 영양제       None       None  ...  causality       None     3
# 105             클렌징 로션       None       None  ...       None       None     1
# 106             클렌징 티슈       None       None  ...       None       None     0
# 107         탁상/USB 선풍기       None       None  ...       None       None     1
# 108                탄산수       None       None  ...       None       None     1
# 109               탄산음료       None       None  ...       None       None     0
# 110                토마토       None       None  ...       None       None     0
# 111               파/양파       None       None  ...  causality       None     2
# 112                파김치       None       None  ...       None       None     1
# 113           포도/거봉/체리       None       None  ...       None       None     1
# 114            프로바이오틱스       None       None  ...       None       None     0
# 115         프로폴리스/로얄젤리       None       None  ...       None       None     1
# 116               해초류        None       None  ...       None       None     1
# 117           핸드워시/스크럽       None       None  ...       None       None     0
# 118               핸드크림       None       None  ...  causality  causality     4
# 119             헤어 브러쉬       None       None  ...       None       None     0
# 120         헤어스타일링용 흑채       None       None  ...       None       None     0
# 121             헤어스프레이       None       None  ...       None       None     0
# 122              헤어에센스       None       None  ...       None       None     0
# 123                 호박       None       None  ...       None       None     0
# 124                 홍차       None       None  ...       None       None     0
# 125                환자식       None       None  ...       None       None     0
# 126               황토매트       None       None  ...       None  causality     3
# 127            휴대용 선풍기       None       None  ...       None       None     1
# 128                 히터  causality       None  ...  causality  causality     6
#
# [129 rows x 11 columns]

# %% [markdown]
# ## 1-4. 비정상 상품 최종 인과관계

# %% [markdown]
# * VECM 결과와 VAR 결과 병합

# %%
ush_granger = pd.concat([ush_granger1, ush_granger2], axis=0)
ush_granger.head()
# Out:
# weather   sm_cat       PM10       PM25 avg_ws  ... max_pa     max_ta min_ta total
# 49       벽걸이 에어컨       None       None   None  ...   None  causality   None     2
# 78       에어컨 리모컨       None       None   None  ...   None  causality   None     2
# 88         음용 식초       None       None   None  ...   None  causality   None     2
# 90           입욕제  causality  causality   None  ...   None       None   None     3
# 123          허브차  causality       None   None  ...   None       None   None     1
#
# [5 rows x 11 columns]

# %%
print('인과관계가 하나라도 있는 상품의 개수 : {}'.format(len(ush_granger[ush_granger.total>0].sm_cat)))
print('인과관계가 하나도 없는 상품의 개수 : {}'.format(len(ush_granger[ush_granger.total==0].sm_cat)))
# Out:
# 인과관계가 하나라도 있는 상품의 개수 : 77
# 인과관계가 하나도 없는 상품의 개수 : 57

# %%
ush_granger[ush_granger.total>0].sm_cat.unique() # 인과관계가 하나라도 있는 상품
# Out:
# array(['벽걸이 에어컨', '에어컨 리모컨', '음용 식초', '입욕제', '허브차', '가열식 가습기',
#        '감귤/한라봉/오렌지', '건대추', '건어물 진미채', '견과류 밤', '곡물차', '기능성 아이케어 화장품',
#        '기능성 화장품 세트', '기초 화장용 로션', '기초 화장용 미스트', '기초 화장용 크림', '기타 주스류',
#        '난방용 열풍기', '남성 세트', '남성 쉐이빙', '느타리버섯', '데오드란트', '둥굴레차',
#        '딸기/복분자/블루베리', '라디에이터', '루테인/눈 영양제', '명태/동태', '바디 보습제', '바디 클렌져',
#        '바디케어용 땀패드', '바디케어용 제모제', '보리차', '복합식 가습기', '부추', '브로콜리/셀러리',
#        '비타민', '색조 메이크업 립밤', '색조 메이크업 아이섀도우', '선스프레이', '선케어용 선밤', '소고기 육회',
#        '쌈채소', '양배추/양상추', '어린이영양제', '에어워셔', '오메가3/스쿠알렌 영양제', '온수매트',
#        '온열매트', '온풍기', '요거트/발효유', '유자차', '율무차', '자연식 가습기', '잡곡 씨드류', '장어',
#        '전기온수기', '전기장판', '초음파식 가습기', '초코우유', '카페트매트', '칼슘/철분 영양제',
#        '캡슐/POD커피', '컨벡터', '코코아/핫초코', '콜라겐/코큐텐 영양제', '클렌징 로션',
#        '탁상/USB 선풍기', '탄산수', '파/양파', '파김치', '포도/거봉/체리', '프로폴리스/로얄젤리',
#        '해초류 ', '핸드크림', '황토매트', '휴대용 선풍기', '히터'], dtype=object)

# %% [markdown]
# # 2. 데이터 저장

# %%
sh_granger.to_csv('최종데이터/stationary_causality.csv', encoding='cp949', index=None)
ush_granger.to_csv('최종데이터/nonstationary_causality.csv', encoding='cp949', index=None)
