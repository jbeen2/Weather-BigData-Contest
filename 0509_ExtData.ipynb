# %%
import pandas as pd
import numpy as np

# %%
import requests

# %%
octkw = pd.read_csv("2019.10_이슈키워드.csv", encoding="cp949")
octkw.head()
# Out:
#    strd_date kwd_nm  sdrs_scor_val  kwd_doc_num     chnl_nm
# 0   20191001    후원금         566.15        12720  ko.twitter
# 1   20191001   영업이익         562.47         2763  ko.twitter
# 2   20191001    공기업         544.26         3669  ko.twitter
# 3   20191001    결제일         531.47         1721  ko.twitter
# 4   20191001    과징금         518.58         1535  ko.twitter

# %%
octkw[octkw.strd_date==20191001]
# Out:
#     strd_date kwd_nm  sdrs_scor_val  kwd_doc_num     chnl_nm
# 0    20191001    후원금         566.15        12720  ko.twitter
# 1    20191001   영업이익         562.47         2763  ko.twitter
# 2    20191001    공기업         544.26         3669  ko.twitter
# 3    20191001    결제일         531.47         1721  ko.twitter
# 4    20191001    과징금         518.58         1535  ko.twitter
# 5    20191001     해직         512.87         2038  ko.twitter
# 6    20191001     예산         511.35        14018  ko.twitter
# 7    20191001     물가         506.30         2673  ko.twitter
# 8    20191001     임금         503.81        12669  ko.twitter
# 9    20191001  소셜커머스         501.90         1246  ko.twitter
# 10   20191001    기부금         492.51         3479  ko.twitter
# 11   20191001     증세         482.32         3662  ko.twitter
# 12   20191001     잔고         471.31         6238  ko.twitter
# 13   20191001   재능기부         470.40         1878  ko.twitter
# ...

# %%
key = '8H1yac%2Bb0yetY2Waad%2BQIRU43O17onRUd7iR0k2p6%2B4i0yNYn3ym0cXgt3ZqWrR9uFw%2BDu%2B5quHbsXxjpsw5ng%3D%3D'

# %%
def getPriceItemList():
    
    '''
    공공데이터포털 품목 리스트 조회 OPEN API  
    '''
    
    url = f'http://data.insight.go.kr/openapi/service/PriceItemList/getPriceItemList?ServiceKey={key}'
    response = requests.get(url)
    # items = response.text
    # items = response.xml()['response']['body']['items']['item']
    # items = pd.DataFrame(items)
    # holidays['locdate'] = holidays['locdate'].astype(str).apply(lambda x : '-'.join([x[:4], x[4:6], x[6:]]))
    
    return response

# %%
getPriceItemList()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# ...
