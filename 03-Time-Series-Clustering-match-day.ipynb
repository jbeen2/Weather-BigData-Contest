# %% [markdown]
# # Time Series Clustering

# %% [markdown]
# ## 0. 데이터 불러오기

# %%
# !pip install tslearn
# Out:
# Collecting tslearn
#   Downloading https://files.pythonhosted.org/packages/95/98/9a67e2869a8b1416eb6e6fd5e69c56f86869980403b18f30bdb5783ade9d/tslearn-0.5.0.5-cp37-cp37m-manylinux2010_x86_64.whl (790kB)
#      |████████████████████████████████| 798kB 3.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from tslearn) (1.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.22.2.post1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.29.23)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from tslearn) (0.51.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->tslearn) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->tslearn) (56.1.0)
# Installing collected packages: tslearn
# Successfully installed tslearn-0.5.0.5

# %%
import numpy as np
import pandas as pd
import datetime
from tqdm.notebook import tqdm
tqdm.pandas()

import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns
# %matplotlib inline

rc('font', family='MalgunGothic')
plt.rcParams['axes.unicode_minus'] = False
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
from tslearn.generators import random_walks
from tslearn.clustering import TimeSeriesKMeans
from sklearn.metrics import silhouette_score
# Out:
# /usr/local/lib/python3.7/dist-packages/tslearn/clustering/kmeans.py:17: UserWarning: Scikit-learn <0.24 will be deprecated in a future release of tslearn
#   "Scikit-learn <0.24 will be deprecated in a "

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/기상청/데이터')

# %%
data = pd.read_csv('data.csv', encoding='CP949')

# %%
data.head()
# Out:
#        date sex  age big_cat sm_cat  qty       cnt
# 0  20180101   F   20      식품    가공란   37  0.480964
# 1  20180101   F   30      식품    가공란   16  0.480964
# 2  20180101   F   40      식품    가공란    9  0.480964
# 3  20180101   F   50      식품    가공란    3  0.480964
# 4  20180101   M   20      식품    가공란   13  0.480964

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ## 2-1. 2018년, 2019년 요일 맞추기

# %%
data['year'] = data['date'].progress_apply(lambda x :str(x)[:4])
buy_2018 = data[data.year=='2018'][['date', 'sex', 'age', 'big_cat', 'sm_cat', 'qty']]
buy_2019 = data[data.year=='2019'][['date', 'sex', 'age', 'big_cat', 'sm_cat', 'qty']]
buy_2018['date'] = buy_2018['date'].progress_apply(lambda x : pd.to_datetime(str(x), format='%Y%m%d'))
buy_2019['date'] = buy_2019['date'].progress_apply(lambda x : pd.to_datetime(str(x), format='%Y%m%d'))
buy_2018.shape, buy_2019.shape
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2056899.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1005487.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1051412.0), HTML(value='')))
# ((1005487, 6), (1051412, 6))

# %%
buy_2018["date"] = buy_2018["date"] + datetime.timedelta(days=-1)
buy_2018["date"] = buy_2018["date"].progress_apply(lambda x : x.replace(year=2018, month=12, day=31) if x==datetime.date(2017, 12, 31) else x)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1005487.0), HTML(value='')))

# %%
buy_2018_cat = buy_2018.groupby(['date', 'sm_cat']).sum('qty').reset_index()[['date', 'sm_cat', 'qty']]
buy_2019_cat = buy_2019.groupby(['date', 'sm_cat']).sum('qty').reset_index()[['date', 'sm_cat', 'qty']]
buy_2018_cat["date"] = buy_2018_cat["date"].progress_apply(lambda x : str(x)[5:10])
buy_2019_cat["date"] = buy_2019_cat["date"].progress_apply(lambda x : str(x)[5:10])
buy_2018_ts = pd.pivot_table(buy_2018_cat, index="sm_cat", columns="date", values="qty")
buy_2019_ts = pd.pivot_table(buy_2019_cat, index="sm_cat", columns="date", values="qty")
buy_2018_ts.shape, buy_2019_ts.shape
# Out:
# HBox(children=(FloatProgress(value=0.0, max=133489.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=134218.0), HTML(value='')))
# ((383, 365), (383, 365))

# %% [markdown]
# ## 2-2. 결측값

# %%
buy_2018_ts = buy_2018_ts.fillna(0)
buy_2019_ts = buy_2019_ts.fillna(0)

# %% [markdown]
# ## 2-3. 평균

# %%
buy_ts = (buy_2018_ts + buy_2019_ts)/2

# %% [markdown]
# ## 2-4. 데이터 정규화

# %%
avg_lst = []; std_lst = []
for idx, row in tqdm(buy_ts.iterrows()):
    avg_lst.append(row.mean())
    std_lst.append(row.std())
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
buy_ts['avg'] = avg_lst
buy_ts['std'] = std_lst
buy_ts.head()
# Out:
# date          01-01  01-02  01-03  01-04  ...  12-30  12-31         avg        std
# sm_cat                                    ...
# 가공란           197.0  200.5  158.5  128.0  ...  203.5  151.0  183.620548  67.424066
# 가스온수기           0.0    0.5    0.0    0.0  ...    0.0    0.0    0.206849   0.359842
# 가열식 가습기        24.5   19.5   21.0   19.0  ...   17.0   11.0    6.782192   8.445435
# 가자미            19.0   26.0   20.0   33.0  ...   31.0   39.0   26.532877  13.565228
# 갈비/찜/바비큐용 돈육   15.0   11.0   13.0    9.0  ...   26.0   29.5   18.553425   6.656652
#
# [5 rows x 367 columns]

# %%
for i in tqdm(range(len(buy_ts))):
    for j in range(365):
        buy_ts.iloc[i,j] = (buy_ts.iloc[i,j] - buy_ts.iloc[i,365])/buy_ts.iloc[i,366]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=383.0), HTML(value='')))

# %%
buy_ts = buy_ts.drop(['avg','std'], axis=1)

# %%
buy_ts.head()
# Out:
# date             01-01     01-02     01-03  ...     12-29     12-30     12-31
# sm_cat                                      ...
# 가공란           0.198437  0.250348 -0.372575  ... -0.676621  0.294842 -0.483812
# 가스온수기        -0.574834  0.814666 -0.574834  ... -0.574834 -0.574834 -0.574834
# 가열식 가습기       2.097915  1.505880  1.683490  ...  0.973047  1.209862  0.499419
# 가자미          -0.555308 -0.039283 -0.481590  ... -0.223577  0.329307  0.919050
# 갈비/찜/바비큐용 돈육 -0.533816 -1.134718 -0.834267  ...  0.592877  1.118667  1.644457
#
# [5 rows x 365 columns]

# %% [markdown]
# # 3. Time Series Clustering

# %% [markdown]
# * DTW

# %% [markdown]
# ### 3-1. 최적의 k

# %%
def visualize_elbowmethod(data, param_init='random', param_n_init=10, param_max_iter=300):
    distortions = []
    for i in tqdm(range(2, 7)):
        ts_clustering = TimeSeriesKMeans(n_clusters=i, max_iter=param_max_iter, random_state=1234, metric = 'dtw')
        ts_clustering.fit(data)
        distortions.append(ts_clustering.inertia_)
    return distortions

# %%
# 하나에 10분
distortions = visualize_elbowmethod(buy_ts)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
plt.plot(range(2, 7), distortions, marker='o')
plt.xlabel('Number of Cluster')
plt.ylabel('Distortion')
plt.show()

# %% [markdown]
# * elbow point = 4

# %% [markdown]
# ### 3-2. Clustering

# %%
# 1시간 30분
# %%time
model_dtw = TimeSeriesKMeans(n_clusters=4, init='random', n_init=10, max_iter=300, random_state=1234, metric = 'dtw').fit(buy_ts)
# Out:
# CPU times: user 1h 17min 23s, sys: 12min 36s, total: 1h 29min 59s
# Wall time: 1h 18min 8s

# %%
result_dtw = model_dtw.predict(buy_ts)
# Out:
# /usr/local/lib/python3.7/dist-packages/tslearn/utils/utils.py:89: UserWarning: 2-Dimensional data passed. Assuming these are 383 1-dimensional timeseries
#   '{} 1-dimensional timeseries'.format(X.shape[0]))

# %%
buy_ts['cluster'] = result_dtw

# %%
buy_ts.head()
# Out:
# date             01-01     01-02     01-03  ...     12-30     12-31  cluster
# sm_cat                                      ...
# 가공란           0.198437  0.250348 -0.372575  ...  0.294842 -0.483812        3
# 가스온수기        -0.574834  0.814666 -0.574834  ... -0.574834 -0.574834        3
# 가열식 가습기       2.097915  1.505880  1.683490  ...  1.209862  0.499419        0
# 가자미          -0.555308 -0.039283 -0.481590  ...  0.329307  0.919050        3
# 갈비/찜/바비큐용 돈육 -0.533816 -1.134718 -0.834267  ...  1.118667  1.644457        2
#
# [5 rows x 366 columns]

# %%
for i in range(4):
    clusters = buy_ts[buy_ts['cluster']==i]
    clusters.drop(['cluster'], axis=1, inplace=True)
    plt.figure(figsize=(20,6))
    plt.plot(clusters.T)
    plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
plt.rcParams["figure.figsize"]=(20,6)
buy_ts.groupby(['cluster']).mean().T.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data_final = buy_ts.reset_index()

# %%
data_final.to_csv('/content/drive/MyDrive/기상청/데이터/cluster_dtw_match_day.csv', encoding='CP949', index = False)

# %%
# 확인
pd.read_csv('/content/drive/MyDrive/기상청/데이터/cluster_dtw_match_day.csv', encoding='CP949')
# Out:
#            sm_cat     01-01     01-02  ...     12-30     12-31  cluster
# 0             가공란  0.198437  0.250348  ...  0.294842 -0.483812        3
# 1           가스온수기 -0.574834  0.814666  ... -0.574834 -0.574834        3
# 2         가열식 가습기  2.097915  1.505880  ...  1.209862  0.499419        0
# 3             가자미 -0.555308 -0.039283  ...  0.329307  0.919050        3
# 4    갈비/찜/바비큐용 돈육 -0.533816 -1.134718  ...  1.118667  1.644457        2
# ..            ...       ...       ...  ...       ...       ...      ...
# 378          황토매트  0.627084  0.627084  ...  0.833847 -0.199965        1
# 379             회  0.165503 -0.041568  ...  1.961411  1.266658        0
# 380       휴대용 선풍기 -0.555509 -0.611009  ... -0.517085 -0.598202        1
# 381           흰우유  0.742728  1.051335  ...  0.753130  0.208734        3
# 382            히터  1.002933  2.241263  ...  0.944258  0.314285        0
#
# [383 rows x 367 columns]

# %%
pd.set_option('display.max_rows', 2000)

# %%
for i in range(4):
    print("클러스터",i)
    print("소분류 개수: ",data_final[data_final['cluster']==i]['sm_cat'].shape[0])
    print(data_final[data_final['cluster']==i]['sm_cat'])
    print('======='*10)
# Out:
# 클러스터 0
# 소분류 개수:  67
# 2            가열식 가습기
# 8         감귤/한라봉/오렌지
# 10              감말랭이
# 21            건어물 멸치
# 24            건어물 황태
# 31             견과류 밤
# 40               곡물차
# 43            곶감/반건시
# 46              과일세트
# 51              굴 생물
# 52             굴비/조기
# 61         기초 화장용 로션
# 65      기초 화장용 오일/앰플
# 66         기초 화장용 크림
# 74           난방용 열풍기
# 78             남성 세트
# 99            대게/킹크랩
# 102           도라지/더덕
# 103              돈풍기
# 104            돼지 곱창
# 107      딸기/복분자/블루베리
# 109            라디에이터
# 133           바디 보습제
# 134            바디 세트
# 165          복합식 가습기
# 189       색조 메이크업 립밤
# 190      색조 메이크업 립스틱
# 199    색조 메이크업 아이섀도우
# 201              생선류
# 213        소고기 등심/안심
# 216            수산 생물
# 230              시금치
# 240             양념우육
# 249             에어워셔
# 260               옥돔
# 265              온풍기
# 271              유자차
# 272           유제품 음료
# 273              율무차
# 278         인삼/수삼/산삼
# 280              입욕제
# 281          자연식 가습기
# 287            전기온수기
# 289            전복 생물
# 290              전통주
# 295               조개
# 298           차 선물세트
# 303         초음파식 가습기
# 312              컨벡터
# 313          코코아/핫초코
# 334             표고버섯
# 337              풋크림
# 341       프로폴리스/로얄젤리
# 344              한우육
# 347             해초류
# 349             핸드크림
# 358       헤어스타일링용 흑채
# 360            헤어에센스
# 365             혼합견과
# 366              혼합곡
# 368          홍삼 분말/환
# 369            홍삼 음료
# 370         홍삼/인삼 제품
# 371          홍삼액/홍삼정
# 372        홍삼절편/홍삼정과
# 379                회
# 382               히터
# Name: sm_cat, dtype: object
# ======================================================================
# 클러스터 1
# 소분류 개수:  94
# 7                 감/홍시
# 11                  감자
# 15                 건대추
# 25                 건자두
# 26                 건포도
# 33           견과류 카카오닙스
# 37                  계란
# 39          고추/피망/파프리카
# 41             공기정화 용품
# 42               공기청정기
# 45                 과일류
# 68              기타 주스류
# 70                 김치류
# 77              남성 선케어
# 85                 냉풍기
# 86          네일 메이크업 용품
# 87             네일관리 소품
# 89                네일세트
# 96        다이어트용 헬스보충식품
# 100               더치커피
# 101              데오드란트
# 111              레몬/자몽
# 117            멀티형 에어컨
# 123                무김치
# 125                물김치
# 126                미나리
# 127          미숫가루/곡물가루
# 130            밀크티/티라떼
# 131        바나나/파인애플/망고
# 132              바나나우유
# 136             바디 클렌져
# 137          바디케어용 땀패드
# 141          바디케어용 제모제
# 146               배추김치
# 154     베이스 메이크업용 쿠션팩트
# 156    베이스 메이크업용 파우더팩트
# 157    베이스 메이크업용 파운데이션
# 158     베이스 메이크업용 프라이머
# 159            벽걸이 에어컨
# 160          벽걸이형 냉온풍기
# 161           벽걸이형 선풍기
# 164         복분자/석류/과실즙
# 167          뷰티 눈썹정리도구
# 170              뷰티 타투
# 174           뷰티용 기름종이
# 200            생닭/닭부분육
# 202                 생수
# 204               샤워코롱
# 206                선로션
# 207              선스프레이
# 209            선케어용 선밤
# 210                선크림
# 211               선파우더
# 214             소고기 육회
# 221          스킨케어 마스크팩
# 225            스킨케어 코팩
# 227          스탠드형 냉온풍기
# 228           스탠드형 에어컨
# 231             식혜/수정과
# 236               아이스티
# 237               애프터선
# 244             어린이 음료
# 248            업소용 선풍기
# 251            에어컨 리모컨
# 252                에이드
# 258              오이/가지
# 261                옥수수
# 263               온수매트
# 274              음용 식초
# 276            이동형 에어컨
# 277               이온음료
# 288               전기장판
# 292           절임배추/김치속
# 294                제습기
# 300           참외/메론/수박
# 304               초코우유
# 305              카페 푸드
# 307              카페트매트
# 320             클렌징 티슈
# 323             키위/참다래
# 324         탁상/USB 선풍기
# 325                탄산수
# 326               탄산음료
# 328                토마토
# 332                팩도구
# 333           포도/거봉/체리
# 335              풋스프레이
# 339        프라페/버블티 파우더
# 340            프로바이오틱스
# 351                허브차
# 375              화장 비누
# 377                환자식
# 378               황토매트
# 380            휴대용 선풍기
# Name: sm_cat, dtype: object
# ======================================================================
# 클러스터 2
# 소분류 개수:  80
# 4           갈비/찜/바비큐용 돈육
# 6                     갈치
# 12                   갓김치
# 16                   건망고
# 17                  건바나나
# 19               건어물 노가리
# 22                건어물 쥐포
# 23               건어물 진미채
# 28                   견과류
# 30             견과류 마카다미아
# 32              견과류 잣/은행
# 34               견과류 캐슈넛
# 35             견과류 피스타치오
# 49             구이/수육용 돈육
# 54          기능성 링클케어 화장품
# 55          기능성 모공관리 화장품
# 59          기능성 화이트닝 화장품
# 60            기능성 화장품 세트
# 67                기타 농산물
# 69             기타 한방/환제품
# 71                    꽃게
# 82                 남성 크림
# 88                 네일리무버
# 90                  네일아트
# 91                  네일컬러
# 92                  네일케어
# 110                  랍스타
# 118              메이크업 박스
# 121                명태/동태
# 122                 무/배추
# 124                   문어
# 139          바디케어용 볼륨업크림
# 140            바디케어용 슬리밍
# 142           바디케어용 청 결제
# 144                  반찬류
# 148          베이스 메이크업 세트
# 150       베이스 메이크업용 CC크림
# 152    베이스 메이크업용 메이크업베이스
# 153        베이스 메이크업용 컨실러
# 155      베이스 메이크업용 트윈케이크
# 169               뷰티 손거울
# 171               뷰티 헤어캡
# 175           뷰티용 면봉/귀이개
# 176               뷰티용 뷰러
# 177              뷰티용 샤프너
# 178           뷰티용 여드름압출기
# 182                 산림욕기
# 183                   삼치
# 184                 상황버섯
# 186                새우/대하
# 192         색조 메이크업 마스카라
# 193          색조 메이크업 볼터치
# 194           색조 메이크업 세트
# 195       색조 메이크업 속눈썹영양제
# 196     색조 메이크업 쉐딩/하이라이터
# 197        색조 메이크업 아이라이너
# 217                 수입우육
# 222             스킨케어 수면팩
# 224           스킨케어 워시오프팩
# 226            스킨케어 필오프팩
# 229            스피루리나 영양제
# 239                양념 돈육
# 243              어란(생선알)
# 253                 여성향수
# 254              연어/훈제연어
# 266               옻/칡/쑥즙
# 284                   장어
# 316               클렌징 로션
# 319               클렌징 크림
# 327              태닝용 선크림
# 330                 파/양파
# 336              풋워시/스크럽
# 338                  풋패치
# 342            한방 분말/환제품
# 346               해조류 미역
# 353               헤어 브러쉬
# 354               헤어매니큐어
# 363               헤어케어세트
# 367                홍삼 간식
# 373                   홍어
# Name: sm_cat, dtype: object
# ======================================================================
# 클러스터 3
# 소분류 개수:  142
# 0                  가공란
# 1                가스온수기
# 3                  가자미
# 5               갈비용 우육
# 9           감마리놀렌산 영양제
# 13                 건강즙
# 14              건강즙/녹용
# 18             건어물 건새우
# 20           건어물 마른오징어
# 27                 게장류
# 29              견과류 땅콩
# 36              견과류 호두
# 38                 고등어
# 44                 과실차
# 47          과일채소 분말/분태
# 48            과채 음료/주스
# 50              국내산 돈육
# 53       글루코사민/키토산 영양제
# 56        기능성 아이케어 화장품
# 57        기능성 영양보습 화장품
# 58       기능성 트러블케어 화장품
# 62          기초 화장용 미스트
# 63           기초 화장용 스킨
# 64          기초 화장용 에센스
# 72                  나물
# 73                  낙지
# 75               남성 로션
# 76             남성 메이크업
# 79              남성 쉐이빙
# 80               남성 스킨
# 81              남성 에센스
# 83              남성 클렌징
# 84                남성향수
# 93                  녹차
# 94               느타리버섯
# 95             다이어트보조식
# 97               닭 양념육
# 98                닭가슴살
# 105                 두유
# 106               둥굴레차
# 108               딸기우유
# 112          루테인/눈 영양제
# 113                 린스
# 114           립앤아이 리무버
# 115               마/야콘
# 116              마늘/생강
# 119           메이크업 브러쉬
# 120               메추리알
# 128               미용가위
# 129              믹스 채소
# 135             바디 스크럽
# 138          바디케어용 때비누
# 143             반건조고구마
# 145           배/포도/과일즙
# 147                백김치
# 149     베이스 메이크업용 BB크림
# 151    베이스 메이크업용 가루파우더
# 162                보리차
# 163                보일러
# 166                 부추
# 168         뷰티 속눈썹/쌍꺼풀
# 172             뷰티 화장솜
# 173      뷰티 화장품 공병/케이스
# 179           브로콜리/셀러리
# 180                비타민
# 181         비타민/화이바 음료
# 185              새송이버섯
# 187       색조 메이크업 립글로스
# 188       색조 메이크업 립라이너
# 191        색조 메이크업 립틴트
# 198      색조 메이크업 아이브로우
# 203           생식/선식 분말
# 205                 샴푸
# 208                 선식
# 212               세안도구
# 215             손톱정리도구
# 218       숙취/에너지/건강 음료
# 219           스크럽/필링크림
# 220           스킨케어 곡물팩
# 223        스킨케어 시트마스크팩
# 232              신발건조기
# 233                  쌀
# 234                쌈채소
# 235         아몬드유/코코넛밀크
# 238             야채/호박즙
# 241            양배추/양상추
# 242             양파/마늘즙
# 245             어린이영양제
# 246              어린이홍삼
# 247           어린잎/새싹채소
# 250               에어커튼
# 255               영지버섯
# 256          오리고기/훈제오리
# 257      오메가3/스쿠알렌 영양제
# 259                오징어
# 262               옥수수차
# 264               온열매트
# 267            요거트/발효유
# 268              우엉/연근
# 269               원두커피
# 270          윙봉/닭다리/날개
# 275              의류건조기
# 279             인스턴트커피
# 282                 잡곡
# 283             잡곡 씨드류
# 285         장조림/카레용 돈육
# 286            저/무지방우유
# 291                전통차
# 293                젓갈류
# 296                주꾸미
# 297            중대형 에어컨
# 299            차/곡물 음료
# 301            천장형 에어컨
# 302             초유 영양제
# 306          카페용 초콜릿시럽
# 308          칼슘/철분 영양제
# 309           캡슐/POD커피
# 310             커피용 프림
# 311               커피음료
# 314        콜라겐/코큐텐 영양제
# 315             콩나물/숙주
# 317             클렌징 오일
# 318           클렌징 워터/젤
# 321              클렌징 폼
# 322           클로렐라 영양제
# 329              트리트먼트
# 331                파김치
# 343               한방재료
# 345            해조류 다시마
# 348           핸드워시/스크럽
# 350               향수세트
# 352           헛개/가시오가피
# 355               헤어무스
# 356        헤어스타일링용 염색약
# 357         헤어스타일링용 펌제
# 359             헤어스프레이
# 361               헤어왁스
# 362                헤어젤
# 364                 호박
# 374                 홍차
# 376              화장 퍼프
# 381                흰우유
# Name: sm_cat, dtype: object
# ======================================================================
